# %%
# Out:
# /Users/oz

# %%
    #四大種類依word count出來特性排名
    唇膏:
    保濕,持久,顯色,自然,透亮,飽和,推勻,遮,上色,黏膩

    眼線筆:
    暈開,上色,持久,顯色,飽和,推勻,透亮,保濕

    眉筆:
    上色,自然,持久,暈開,顯色,推勻,保濕

    粉底液:
    遮,保濕,持久,透亮,推勻,自然,清爽,浮粉

# %%
# adv area
comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

replaceF(test1,comma_,'，')
replaceF(test1,long_,'持久')
replaceF(test1,short_,'脫妝')
replaceF(test1,cover_,'遮')
replaceF(test1,nature_,'自然')
replaceF(test1,none_,'')
replaceF(test1,Water_,'保濕')
replaceF(test1,Dry_,'乾')
replaceF(test1,blendout_,'推勻')
replaceF(test1,fresh_,'清爽')
replaceF(test1,stick_,'服貼')
replaceF(test1,Waterpro_,'防水')
replaceF(test1,UnWaterpro_,'暈開')
replaceF(test1,Bright_,'透亮')
replaceF(test1,ColorSaturation_,'飽和')
replaceF(test1,ShowColor_,'顯色')
replaceF(test1,EasytoCo_,'上色')
replaceF(test1,soft_,'軟')


replaceF(test1,small_,'小')
replaceF(test1,compare_,'更')
replaceF(test1,super_,'超')
replaceF(test1,perfect_,'非常')

replaceF(test1,Nsmall_,'不易')
replaceF(test1,No_,'沒有')
replaceF(test1,Nsuper_,'無法')
# Out:
# ，，，是，
# 我也不過是XD
# 我也不過是XD
# 我也不過是XD

# %%
# .replace("滑順","軟").replace("柔軟","軟")...-->['滑順', '柔軟', '好化', '好畫', '柔', '細']
def cha(k):
    ok=[]
    ky=k.replace('.replace','').replace('(','').replace(')','').replace(',',':').replace('\t','').replace(' ','').replace('"','').split('\n')
    for i in ky:
        i=i.split(':')[0]
        ok.append(i)
    print(ok)

# %%
y=""".replace("滑順","軟")
.replace("柔軟","軟")
.replace("好化","軟")
.replace("好畫","軟")
.replace("柔","軟")
.replace("細","軟")"""
cha(y)
# Out:
# ['滑順', '柔軟', '好化', '好畫', '柔', '細']

# %%
#catch the adv in the list and give every sentence's score
def ScoreF(i):
    if '無法' in i :
        score=-1.75
        deny.append(i)
        return(score)

    elif '沒有' in i :
        score=-1.5
        deny2.append(i)
        return(score)
    elif '不易' in i :
        score=-1.25  
        deny3.append(i)
        return(score)
    elif '非常' in i :
        score=2.25
        good.append(i)
        return(score)
    elif '超' in i :
        score=2
        good1.append(i)
        return(score)
    elif '很' in i :
        score=1.75
        good2.append(i)
        return(score)
    elif '更' in i :
        score=1.5
        good3.append(i)
        return(score)
    elif '小' in i :
        score=1.25
        good4.append(i)
        return(score)
    else:
        score=1
        normal.append(i)
        return(score)

# %%
#replace the similar word to special word in the content
def replaceF(a,b,c):

    for i in b:
        a=a.replace(i,c)
    return(a)

# %%
#唇膏權重前十名依序排列:保濕,持久,顯色,自然,透亮,飽和,推勻,遮,上色,黏膩
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/Oz_jieba/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/唇膏/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==len(files):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    if test['comments']==[]:
        k+=1
        continue
    while True:
        try:
                
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')


        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)



        
        j+=1
    #print(Dry)

    try:
        dic['Moisture']=round((Water1-Dry1)*10/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['Moisture']=0
    try:
        dic['Durability']=round((mainLong1-mainShort1)*9/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['Durability']=0
    try:
        dic['Distinctness']=round((ShowColor1)*8/len(ShowColor),4)
    except ZeroDivisionError:
        dic['Distinctness']=0
    try:
        dic['Naturalness']=round((nature1)*7/len(nature),4)
    except ZeroDivisionError:
        dic['Naturalness']=0
    try:
        dic['Transparency']=round((Bright1)*6/len(Bright),4)
    except ZeroDivisionError:
        dic['Transparency']=0
    try:
        dic['Saturation']=round((ColorSaturation1)*5/len(ColorSaturation),4)
    except ZeroDivisionError:
        dic['Saturation']=0
    try:
        dic['Pushing_evenness']=round((blendout1-Unblendout1)*4/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['Pushing_evenness']=0
    try:
        dic['Concealer']=round((cover1)*3/len(cover),4)
    except ZeroDivisionError:
        dic['Concealer']=0
    try:
        dic['Coloring']=round((EasytoCo1)*2/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['Coloring']=0
    try:
        dic['Refreshing']=round((fresh1-unfresh1)/len(fresh+unfresh),4)
    except ZeroDivisionError:
        dic['Refreshing']=0
        
    dic['pro_class']='唇膏'
    dic['product_ID']=files[k].replace('.json','').split('/')[-1].split('_')[0]
    #print(dic)    
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
    #print(Water)
with open('/Users/oz/Desktop/test/Score/lips_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'10106_one_color': {'Coloring': 0,
#   'Concealer': 0,
#   'Distinctness': 0,
#   'Durability': 0,
#   'Moisture': 17.5,
#   'Naturalness': 0,
#   'Pushing_evenness': 0,
#   'Refreshing': 0,
#   'Saturation': 0,
#   'Transparency': 0,
#   'pro_class': '唇膏',
#   'product_ID': '10106'},
#  '1049_one_color': {'Coloring': 0,
#   'Concealer': -1.125,
#   'Distinctness': 8.4,
#   'Durability': 4.9091,
#   'Moisture': 9.0079,
#   'Naturalness': 7.7778,
#   'Pushing_evenness': 0,
#   'Refreshing': 0,
#   'Saturation': 5.0,
#   'Transparency': 7.8,
#   'pro_class': '唇膏',
#   'product_ID': '1049'},
#  '11176_one_color': {'Coloring': 0,
#   'Concealer': 0,
#   'Distinctness': 14.0,
#   'Durability': 12.375,
#   'Moisture': -1.6667,
#   'Naturalness': 0,
#   'Pushing_evenness': 0,
#   'Refreshing': 0,
#   'Saturation': 0,
#   'Transparency': 10.5,
#   'pro_class': '唇膏',
#   'product_ID': '11176'},
#  '11237_one_color': {'Coloring': 0,
#   'Concealer': 0,
#   'Distinctness': 14.0,
# ...

# %%
上色度 Coloring
保濕度 Moisture
持久度 Durability
推勻度 Pushing_evenness
防水度 Waterproof
顯色度 Distinctness
自然度 Naturalness
透亮度 Transparency
飽和度 Saturation
遮瑕度 Concealer
服貼度 Sticking
清爽度 Refreshing

# %%
with open('/Users/oz/Documents/makeup/total/唇膏/42060_one_color.json') as f:
    aa=json.load(f)
aa
# Out:
# {'brand': 'KATE TOKYO 凱婷',
#  'comments': [{'affect': ['顯色',
#     '會回購',
#     '遮蓋唇色',
#     '不黏膩',
#     '好氣色',
#     '好上手',
#     '自然',
#     '妝感自然',
#     '價格實在',
#     '豐唇',
#     '好推勻'],
#    'comments_published_time': '2016.07.03',
#    'content': '之前對這個牌子的唇彩並沒有很注意 \xa0 但對它的粉底液有印象某天去屈臣式就這樣給了它挑色包了回家其實我的唇色比較適合在歐美系和日系出的顏色所以最近幾乎都買這些櫃的東西比較多 \xa0 包括粉底液的顏色也是它的保濕度沒有非常好 \xa0 \xa0但也沒有讓我覺得很差 \xa0 至少我不用擦護唇膏就上色了它的顏色非常多 \xa0 \xa0所以在挑色時花了點時間 \xa0 \xa0但讓我非常開心的挑到我最想要的顏色RD-14 \xa0 我覺得是玫瑰色 \xa0 \xa0不會太亮 \xa0 但也不會太暗對於我嘴唇周邊較暗的部分多塗一下就壓過了 \xa0 \xa0還算滿意唇膏中內含一些些細的亮粉 \xa0 \xa0其實我對這個比較在意但好佳在塗了看起來沒那麼明顯有打算等小屈77折時再去挑其他色一下',
#    'user_ID': '425347',
#    'user_score': '6'},
#   {'affect': ['保濕', '光澤'],
#    'comments_published_time': '2016.10.05',
# ...

# %%
#test 
with open('/Users/oz/Documents/makeup/total/唇膏/2781_one_color.json') as f:
    aa=json.load(f)
aa
# Out:
# {'brand': 'Estee Lauder 雅詩蘭黛',
#  'comments': [],
#  'label': ['Estee Lauder 雅詩蘭黛關注品牌', '唇膏系列', '彩妝 > 唇彩 > 唇膏', '美國'],
#  'price': 'NT$ 750',
#  'pro_info': '輕鬆呈現性感雙唇：高光澤感的水透成分，能在塗上脣膏的同時，高度展現耀眼迷人的水嫩光感。唇彩、唇蜜同時上色，一次動作，加倍動人。隨時隨地，輕輕鬆鬆，立即展現唇唇欲動的迷人風采。\n舒適自然柔嫩潤澤：特殊的低融蜜蠟成分，能迅速在雙唇上形成柔軟、滋潤的飽和光澤。固態的低融蜜蠟成分在人體的微溫下，立即於唇上融化成液態蜜質，舒適自然，沒有唇蜜厚重的負擔，卻能展現光澤與柔潤。脣膏內添加了維他命E，更能保護雙唇免於外在環境的傷害，使唇部更加滋潤。\n豐盈色彩艷麗展現：10種最新、最炫、最性感的的選擇，讓生活多采多姿的摩登女郎能隨意\n搭配不同場合與造型，創造出最完美的性感唇色。\n# 501 Vinyl Voltage瑩亮醇釉、# 503 Vinyl Pink粉嫩俏釉\n# 504 Vinyl Poppy罌艷彩釉、# 505 Vinyl Brown秋褐純釉\n# 506 Vinyl Violet羅蘭紫釉、# 507 Vinyl Nude純真裸釉\n# 508 Vinyl Cherry櫻語潤釉、# 509 Vinyl Citrus甜柑香釉\n# 511 Vinyl Fuschia紫彩薰釉、# 512 Vinyl Plum彩梅韻釉\n',
#  'pro_picture': 'https://dg9ugnb21lig7.cloudfront.net/uploads/product_image/2781/1/_250x250_2781_w_250xh_250xfar_C.jpg',
#  'product_ID': '2781',
#  'product_color': 'one_color',
#  'product_name': '純色潤采唇膏 Pure Color Vinyl Gloss Stick',
#  'product_url': 'https://www.urcosme.com/products/2781',
#  'score': '-.-'}

# %%
# test 
#print(deny)
#print(deny2)
#print(deny3)
#print(good1)
#print(good2)
print(mainLong1)
print(mainShort)
print(mainShort1)
print(cover)
print(cover1)

dic
# Out:
# 2.25
# ['頗耐看..不易容易脫妝..']
# -1.25
# ['提供豐富的遮力', 'BROWN老師示範的是另一個色粉紅色這款用起來很遮唇紋上小就很顯色', '高遮', '是白肌～這張圖直接素顏就擦上唇膏很遮很遮原本唇色']
# 5.5
# {'product_ID': '9894',
#  '上色度': -0.5,
#  '保濕度': -1.5972,
#  '持久度': 6.3,
#  '推勻度': 1.5714,
#  '清爽度': 0,
#  '種類': '唇膏',
#  '自然度': 6.4167,
#  '透亮度': 10.5,
#  '遮瑕度': 4.125,
#  '顯色度': 9.25,
#  '飽和度': 6.6667}

# %%
#眼線筆前八名:暈開,上色,持久,顯色,飽和,推勻,透亮,保濕
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/Oz_jieba/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/眼線筆/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==(len(files)):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0
    
    with open(files[k]) as f:
        test=json.load(f)
    if test['comments']==[]:
        k+=1
        continue
    while True:
        try:
                
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)



        j+=1
        
    try:
        dic['Waterproof']=round((Waterpro1-UnWaterpro1)*8/len(Waterpro+UnWaterpro),4)
    except ZeroDivisionError:
        dic['Waterproof']=0
    try:
        dic['Coloring']=round((EasytoCo1)*7/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['Coloring']=0
        
    try:
        dic['Durability']=round((mainLong1-mainShort1)*6/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['Durability']=0
    try:
        dic['Distinctness']=round((ShowColor1)*5/len(ShowColor),4)
    except ZeroDivisionError:
        dic['Distinctness']=0
    try:
        dic['Saturation']=round((ColorSaturation1)*4/len(ColorSaturation),4)
    except ZeroDivisionError:
        dic['Saturation']=0    
    try:
        dic['Pushing_evenness']=round((blendout1-Unblendout1)*3/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['Pushing_evenness']=0
    try:
        dic['Transparency']=round((Bright1)*2/len(Bright),4)
    except ZeroDivisionError:
        dic['Transparency']=0    
    
    try:
        dic['Moisture']=round((Water1-Dry1)*1/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['Moisture']=0

    dic['pro_class']='眼線筆'
    dic["product_ID"]=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1

with open('/Users/oz/Desktop/test/Score/Eyeliner_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'10510': {'Coloring': 6.4167,
#   'Distinctness': 7.75,
#   'Durability': -1.9286,
#   'Moisture': 0,
#   'Pushing_evenness': 4.125,
#   'Saturation': 0,
#   'Transparency': 0,
#   'Waterproof': -2.381,
#   'pro_class': '眼線筆',
#   'product_ID': '10510'},
#  '1091': {'Coloring': -5.25,
#   'Distinctness': 0,
#   'Durability': 0,
#   'Moisture': 0,
#   'Pushing_evenness': 0,
#   'Saturation': 0,
#   'Transparency': 0,
#   'Waterproof': -3.3333,
#   'pro_class': '眼線筆',
#   'product_ID': '1091'},
#  '11235': {'Coloring': 6.9079,
#   'Distinctness': 5.0,
#   'Durability': -0.375,
#   'Moisture': 0.0,
#   'Pushing_evenness': 0,
#   'Saturation': 4.0,
#   'Transparency': -1.25,
#   'Waterproof': -2.0263,
#   'pro_class': '眼線筆',
#   'product_ID': '11235'},
#  '11450': {'Coloring': 6.2222,
#   'Distinctness': 0,
#   'Durability': 0,
#   'Moisture': 1.25,
#   'Pushing_evenness': 0,
#   'Saturation': 0,
#   'Transparency': 0,
#   'Waterproof': -3.0,
#   'pro_class': '眼線筆',
# ...

# %%
#眉筆:上色,自然,持久,暈開,顯色,推勻,保濕
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/眉筆/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==(len(files)-1):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    if test['comments']==[]:
        k+=1
        continue
    while True:
        try:
                
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)



        j+=1
    try:
        dic['Coloring']=round((EasytoCo1)*7/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['Coloring']=0
    try:
        dic['Naturalness']=round((nature1)*6/len(nature),4)
    except ZeroDivisionError:
        dic['Naturalness']=0
 
            
    try:
        dic['Durability']=round((mainLong1-mainShort1)*5/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['Durability']=0

    try:
        dic['Waterproof']=round((Waterpro1-UnWaterpro1)*4/len(Waterpro+UnWaterpro),4)
    except ZeroDivisionError:
        dic['Waterproof']=0


    try:
        dic['Distinctness']=round((ShowColor1)*3/len(ShowColor),4)
    except ZeroDivisionError:
        dic['Distinctness']=0
        
    try:
        dic['Pushing_evenness']=round((blendout1-Unblendout1)*2/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['Pushing_evenness']=0

    try:
        dic['Moisture']=round((Water1-Dry1)*1/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['Moisture']=0

    dic['pro_class']='眉筆'
    dic['product_ID']=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/Score/EyebrowPen_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'10063': {'Coloring': 6.75,
#   'Distinctness': 5.5,
#   'Durability': 1.8182,
#   'Moisture': 0,
#   'Naturalness': 7.5,
#   'Pushing_evenness': 0,
#   'Waterproof': -7.3333,
#   'pro_class': '眉筆',
#   'product_ID': '10063'},
#  '1063': {'Coloring': 5.9062,
#   'Distinctness': 4.125,
#   'Durability': 4.6875,
#   'Moisture': 0,
#   'Naturalness': 8.7,
#   'Pushing_evenness': 0,
#   'Waterproof': 0,
#   'pro_class': '眉筆',
#   'product_ID': '1063'},
#  '11344': {'Coloring': 5.6724,
#   'Distinctness': 3.0,
#   'Durability': 3.2143,
#   'Moisture': 0,
#   'Naturalness': 8.3571,
#   'Pushing_evenness': 0,
#   'Waterproof': 3.0,
#   'pro_class': '眉筆',
#   'product_ID': '11344'},
#  '11453': {'Coloring': 7.4038,
#   'Distinctness': 4.6875,
#   'Durability': 4.375,
#   'Moisture': 0,
#   'Naturalness': 7.0714,
#   'Pushing_evenness': 0,
#   'Waterproof': -2.3636,
#   'pro_class': '眉筆',
#   'product_ID': '11453'},
#  '12348': {'Coloring': 9.625,
#   'Distinctness': 0,
#   'Durability': 0,
# ...

# %%
#粉底液:遮,保濕,持久,透亮,推勻,自然,清爽,浮粉
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/粉底液/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==len(files):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Unstick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Unstick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    if test['comments']==[]:
        k+=1
        continue
    while True:
        try:
                
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)
            if '浮粉' in i :
                Unstick.append(i)
                Unstick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)



        j+=1
    try:
        dic['Concealer']=round((cover1)*9/len(cover),4)
    except ZeroDivisionError:
        dic['Concealer']=0  
    try:
        dic['Moisture']=round((Water1-Dry1)*8/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['Moisture']=0
    try:
        dic['Durability']=round((mainLong1-mainShort1)*7/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['Durability']=0
    try:
        dic['Transparency']=round((Bright1)*6/len(Bright),4)
    except ZeroDivisionError:
        dic['Transparency']=0 
    try:
        dic['Pushing_evenness']=round((blendout1-Unblendout1)*5/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['Pushing_evenness']=0   
        
    try:
        dic['Naturalness']=round((nature1)*4/len(nature),4)
    except ZeroDivisionError:
        dic['Naturalness']=0   
        
    try:
        dic['Refreshing']=round((fresh1-unfresh1)*3/len(fresh+unfresh),4)
    except ZeroDivisionError:
        dic['Refreshing']=0
        
            
    try:
        dic['Sticking']=round((stick1-Unstick1)*3/len(stick+Unstick),4)
    except ZeroDivisionError:
        dic['Sticking']=0
        
    


        
    dic['pro_class']='粉底液'
    dic['product_ID']=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/Score/Foundation_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'10508': {'Concealer': -4.95,
#   'Durability': -6.5625,
#   'Moisture': -3.3333,
#   'Naturalness': 4.0,
#   'Pushing_evenness': -6.25,
#   'Refreshing': 0,
#   'Sticking': 0,
#   'Transparency': 0,
#   'pro_class': '粉底液',
#   'product_ID': '10508'},
#  '10610': {'Concealer': 11.25,
#   'Durability': 0,
#   'Moisture': 10.0,
#   'Naturalness': -0.5,
#   'Pushing_evenness': 8.125,
#   'Refreshing': 0,
#   'Sticking': 0,
#   'Transparency': 8.25,
#   'pro_class': '粉底液',
#   'product_ID': '10610'},
#  '10814': {'Concealer': 0,
#   'Durability': 10.5,
#   'Moisture': -1.0,
#   'Naturalness': 0,
#   'Pushing_evenness': 0,
#   'Refreshing': 0,
#   'Sticking': 0,
#   'Transparency': 0,
#   'pro_class': '粉底液',
#   'product_ID': '10814'},
#  '11210': {'Concealer': 8.2156,
#   'Durability': 5.4124,
#   'Moisture': -0.7894,
#   'Naturalness': 3.7569,
#   'Pushing_evenness': 2.8675,
#   'Refreshing': 2.7702,
#   'Sticking': 0.8682,
#   'Transparency': 5.0271,
#   'pro_class': '粉底液',
# ...

# %%
上色度 Coloring
保濕度 Moisture
持久度 Durability
推勻度 Pushing_evenness
防水度 Waterproof
顯色度 Distinctness
自然度 Naturalness
透亮度 Transparency
飽和度 Saturation
遮瑕度 Concealer
服貼度 Sticking
清爽度 Refreshing
pro_class
# Out:
# 6
