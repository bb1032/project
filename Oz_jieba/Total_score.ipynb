# %%
comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

replaceF(test1,comma_,'，')
replaceF(test1,long_,'持久')
replaceF(test1,short_,'脫妝')
replaceF(test1,cover_,'遮')
replaceF(test1,nature_,'自然')
replaceF(test1,none_,'')
replaceF(test1,Water_,'保濕')
replaceF(test1,Dry_,'乾')
replaceF(test1,blendout_,'推勻')
replaceF(test1,fresh_,'清爽')
replaceF(test1,stick_,'服貼')
replaceF(test1,Waterpro_,'防水')
replaceF(test1,UnWaterpro_,'暈開')
replaceF(test1,Bright_,'透亮')
replaceF(test1,ColorSaturation_,'飽和')
replaceF(test1,ShowColor_,'顯色')
replaceF(test1,EasytoCo_,'上色')
replaceF(test1,soft_,'軟')


replaceF(test1,small_,'小')
replaceF(test1,compare_,'更')
replaceF(test1,super_,'超')
replaceF(test1,perfect_,'非常')

replaceF(test1,Nsmall_,'不易')
replaceF(test1,No_,'沒有')
replaceF(test1,Nsuper_,'無法')
# Out:
# ，，，是，
# 我也不過是XD
# 我也不過是XD
# 我也不過是XD

# %%
def cha(k):
    ok=[]
    ky=k.replace('.replace','').replace('(','').replace(')','').replace(',',':').replace('\t','').replace(' ','').replace('"','').split('\n')
    for i in ky:
        i=i.split(':')[0]
        ok.append(i)
    print(ok)

# %%
y=""".replace("滑順","軟")
.replace("柔軟","軟")
.replace("好化","軟")
.replace("好畫","軟")
.replace("柔","軟")
.replace("細","軟")"""
cha(y)
# Out:
# ['滑順', '柔軟', '好化', '好畫', '柔', '細']

# %%
def ScoreF(i):
    if '無法' in i :
        score=-1.75
        deny.append(i)
        return(score)

    elif '沒有' in i :
        score=-1.5
        deny2.append(i)
        return(score)
    elif '不易' in i :
        score=-1.25  
        deny3.append(i)
        return(score)
    elif '非常' in i :
        score=2.25
        good.append(i)
        return(score)
    elif '超' in i :
        score=2
        good1.append(i)
        return(score)
    elif '很' in i :
        score=1.75
        good2.append(i)
        return(score)
    elif '更' in i :
        score=1.5
        good3.append(i)
        return(score)
    elif '小' in i :
        score=1.25
        good4.append(i)
        return(score)
    else:
        score=1
        normal.append(i)
        return(score)

# %%
62.5

# %%
def replaceF(a,b,c):

    for i in b:
        a=a.replace(i,c)
    return(a)

# %%
#唇膏:保濕,持久,顯色,自然,透亮,飽和,推勻,遮,上色,黏膩
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/唇膏/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==len(files):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    while True:
        try:
            if test['comments']==[]:
                k+=1
                break
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)

            else:
                continue



        j+=1

    try:
        dic['保濕度']=round((Water1-Dry1)*10/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['保濕度']=0
    try:
        dic['持久度']=round((mainLong1-mainShort1)*9/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['持久度']=0
    try:
        dic['顯色度']=round((ShowColor1)*8/len(ShowColor),4)
    except ZeroDivisionError:
        dic['顯色度']=0
    try:
        dic['自然度']=round((nature1)*7/len(nature),4)
    except ZeroDivisionError:
        dic['自然度']=0
    try:
        dic['透亮度']=round((Bright1)*6/len(Bright),4)
    except ZeroDivisionError:
        dic['透亮度']=0
    try:
        dic['飽和度']=round((ColorSaturation1)*5/len(ColorSaturation),4)
    except ZeroDivisionError:
        dic['飽和度']=0
    try:
        dic['推勻度']=round((blendout1-Unblendout1)*4/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['推勻度']=0
    try:
        dic['遮瑕度']=round((cover1)*3/len(cover),4)
    except ZeroDivisionError:
        dic['遮瑕度']=0
    try:
        dic['上色度']=round((EasytoCo1)*2/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['上色度']=0
    try:
        dic['清爽度']=round((fresh1-unfresh1)/len(fresh+unfresh),4)
    except ZeroDivisionError:
        dic['清爽度']=0
        
    dic['種類']='唇膏'
    dic[product_ID]=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/lips_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'1028_曖昧水感唇膏_01': {'上色度': 0.3333,
#   '保濕度': 5.5682,
#   '持久度': 4.5,
#   '推勻度': 2.2222,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 10.5,
#   '透亮度': 7.5,
#   '遮瑕度': 4.25,
#   '顯色度': 12.8889,
#   '飽和度': 6.1364},
#  '1028_曖昧水感唇膏_03': {'上色度': 1.4286,
#   '保濕度': 4.7093,
#   '持久度': 9.9643,
#   '推勻度': 4.0833,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 3.2083,
#   '透亮度': 6.0,
#   '遮瑕度': 3.375,
#   '顯色度': 10.1333,
#   '飽和度': 1.25},
#  '1028_曖昧水感唇膏_05': {'上色度': 1.4286,
#   '保濕度': 4.7093,
#   '持久度': 9.9643,
#   '推勻度': 4.0833,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 3.2083,
#   '透亮度': 6.0,
#   '遮瑕度': 3.375,
#   '顯色度': 10.1333,
#   '飽和度': 1.25},
#  '3 Concept Eyes_GLOW JAM STICK _one_color': {'上色度': 2.0,
#   '保濕度': 2.6786,
#   '持久度': -5.625,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.4375,
#   '透亮度': -4.0,
#   '遮瑕度': 5.75,
#   '顯色度': 8.0,
#   '飽和度': 2.9167},
#  '3 Concept Eyes_MOOD RECIPE MATTE LIP COLOR _one_color': {'上色度': -0.5,
#   '保濕度': -6.5789,
#   '持久度': 9.5625,
#   '推勻度': 2.5,
#   '清爽度': 2.25,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -1.5,
#   '遮瑕度': 3.0,
#   '顯色度': 10.6667,
#   '飽和度': 9.1667},
#  '3 Concept Eyes_愛塗鴉唇彩潤澤蠟筆 JUMBO LIP CRAYON_BOHEMIAN PINK': {'上色度': 0.75,
#   '保濕度': -1.0714,
#   '持久度': 9.0,
#   '推勻度': 6.5,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 1.0,
#   '飽和度': 0.625},
#  '3 Concept Eyes_愛塗鴉唇彩潤澤蠟筆 JUMBO LIP CRAYON_MAD RED': {'上色度': 0,
#   '保濕度': -6.4286,
#   '持久度': 12.375,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 2.625,
#   '遮瑕度': 3.0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  '3 Concept Eyes_愛塗鴉唇彩潤澤蠟筆 JUMBO LIP CRAYON_POP ORANGE': {'上色度': 0,
#   '保濕度': -6.4286,
#   '持久度': 12.375,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 2.625,
#   '遮瑕度': 3.0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  '3 Concept Eyes_超顯色唇膏 Glass lip Color_118': {'上色度': 0,
#   '保濕度': -6.4286,
#   '持久度': 12.375,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 2.625,
#   '遮瑕度': 3.0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  '3 Concept Eyes_超顯色唇膏 Glass lip Color_216': {'上色度': -0.25,
#   '保濕度': -2.8,
#   '持久度': 8.1818,
#   '推勻度': 0.5,
#   '清爽度': -0.3333,
#   '種類': '唇膏',
#   '自然度': 8.75,
#   '透亮度': 3.5294,
#   '遮瑕度': 1.5833,
#   '顯色度': 9.52,
#   '飽和度': 8.5},
#  '3 Concept Eyes_超顯色唇膏 Glass lip Color_806': {'上色度': -0.25,
#   '保濕度': -2.8,
#   '持久度': 8.1818,
#   '推勻度': 0.5,
#   '清爽度': -0.3333,
#   '種類': '唇膏',
#   '自然度': 8.75,
#   '透亮度': 3.5294,
#   '遮瑕度': 1.5833,
#   '顯色度': 9.52,
#   '飽和度': 8.5},
#  '3 Concept Eyes_超顯色唇膏 Glass lip Color_908': {'上色度': -0.25,
#   '保濕度': -2.8,
#   '持久度': 8.1818,
#   '推勻度': 0.5,
#   '清爽度': -0.3333,
#   '種類': '唇膏',
#   '自然度': 8.75,
#   '透亮度': 3.5294,
#   '遮瑕度': 1.5833,
#   '顯色度': 9.52,
#   '飽和度': 8.5},
#  'A_PIEU_와일드 매트 립스틱 Wild Matt Lipstick_one_color': {'上色度': -0.25,
#   '保濕度': -2.8,
#   '持久度': 8.1818,
#   '推勻度': 0.5,
#   '清爽度': -0.3333,
#   '種類': '唇膏',
#   '自然度': 8.75,
#   '透亮度': 3.5294,
#   '遮瑕度': 1.5833,
#   '顯色度': 9.52,
#   '飽和度': 8.5},
#  'ABSOLUTE NEW YORK 絕色紐約_霧感啞緻唇膏_one_color': {'上色度': 0,
#   '保濕度': 1.25,
#   '持久度': 13.5,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -0.75,
#   '遮瑕度': 0,
#   '顯色度': 3.3333,
#   '飽和度': 0},
#  'absolution_安全之吻唇膏_11': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'absolution_安全之吻唇膏_19': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'absolution_安全之吻唇膏_8': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ADDICTION 奧可玹_癮炫持久唇膏 LIPSTICK PURE_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'agnes b_新一代水潤豐澤晶亮唇蜜膏 agnesb glossy stick_one_color': {'上色度': 0,
#   '保濕度': 0.0,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 6.75,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'agnes b_絕色超水感唇膏 SPF13_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ALBION_妃思雅蜂漿晶鑚唇膏 EXCIA Glorious Rouge_PK105': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ALBION_妃思雅蜂漿晶鑚唇膏 EXCIA Glorious Rouge_RD303': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Always Black 黑色會_潤炫唇膏8色 Lip stick_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ARITAUM_honey melting tint_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ARITAUM_Wannabe Cushion Tint_one_color': {'上色度': 0,
#   '保濕度': 2.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 14.0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': -14.0,
#   '飽和度': 8.75},
#  'ARTDECO_AD奢華煥彩唇膏_one_color': {'上色度': 2.0,
#   '保濕度': 2.5,
#   '持久度': -1.35,
#   '推勻度': 5.2857,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 6.0,
#   '遮瑕度': -4.5,
#   '顯色度': 0.6667,
#   '飽和度': 0},
#  'ARWIN 雅聞_丹紅亮光唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'AVANCE CHIPIE_糖霜唇彩光澤_11': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'AVANCE CHIPIE_糖霜唇彩光澤_32': {'上色度': 0,
#   '保濕度': 1.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  'AVANCE CHIPIE_糖霜唇彩光澤_52': {'上色度': 0,
#   '保濕度': 1.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  'AVANCE CHIPIE_糖霜唇彩柔滑_30': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'AVANCE CHIPIE_糖霜唇彩柔滑_40': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_嬌灩欲滴唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_持久真采唇膏_one_color': {'上色度': 0,
#   '保濕度': 5.0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_晶璨魔鏡唇膏_one_color': {'上色度': 2.0,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_極霧面絲絨唇膏 True Color Perfectly Matte Lipstick_21563': {'上色度': 3.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_極霧面絲絨唇膏 True Color Perfectly Matte Lipstick_21602': {'上色度': 3.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_極霧面絲絨唇膏 True Color Perfectly Matte Lipstick_21620': {'上色度': 3.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_玩色亮感唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_瓷光亮采唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_絕對綻色唇膏_2054': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_絕對綻色唇膏_67505': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_絕對綻色唇膏_890': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_芳魅無痕唇膏_one_color': {'上色度': 3.5,
#   '保濕度': 0.8333,
#   '持久度': 0.8654,
#   '推勻度': 9.0,
#   '清爽度': 1.125,
#   '種類': '唇膏',
#   '自然度': 12.25,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 11.0,
#   '飽和度': 5.0},
#  'Avon 雅芳_芳魅絲滑唇膏_one_color': {'上色度': 0,
#   '保濕度': 1.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_雅芳滋潤亮光唇膏_one_color': {'上色度': 0,
#   '保濕度': 15.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_雅芳色彩晶璨唇膏_one_color': {'上色度': 0,
#   '保濕度': -12.5,
#   '持久度': -13.5,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Avon 雅芳_雅芳薄漾唇膏_one_color': {'上色度': 0,
#   '保濕度': -10.0,
#   '持久度': -2.25,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 12.0,
#   '飽和度': 0},
#  'Avon 雅芳_頂級金燦唇膏_霧絨雅緻': {'上色度': 0,
#   '保濕度': 22.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Floral Seoul唇膏筆 Floral Seoul Lip Crayon_ND01': {'上色度': 0,
#   '保濕度': 2.0238,
#   '持久度': 3.9375,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 4.75,
#   '透亮度': 7.5,
#   '遮瑕度': 0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  'banila co_Floral Seoul唇膏筆 Floral Seoul Lip Crayon_OR04': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Floral Seoul唇膏筆 Floral Seoul Lip Crayon_PK07': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Floral Seoul啞緻鎖色唇膏 Floral Seoul Colour Fix Matt_MBE104': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Floral Seoul啞緻鎖色唇膏 Floral Seoul Colour Fix Matt_MOR219': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Floral Seoul啞緻鎖色唇膏 Floral Seoul Colour Fix Matt_MPK553': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _BG01': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _OR02': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _PK02': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _PK04': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _PK06': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_珍藏之吻雙效唇膏筆 _PP02': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_蜜吻顯色絲綢唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_閃亮耀目柔滑啞緻唇膏 Kiss Collector Color Fix Satin_Lumiere': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_閃亮耀目柔滑啞緻唇膏 Kiss Collector Color Fix Satin_Seduction': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_Pop of Passio Lip Oil-Balm_one_color': {'上色度': 2.5,
#   '保濕度': 10.0,
#   '持久度': 0,
#   '推勻度': 1.6667,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 1.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Break Away': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Finish First': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Get Ready': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Lead The Way': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Live Large': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Never Say Never': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Rise Up': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bareMinerals_熱辣俏唇礦物唇膏 Marvelous Moxie Lipstick_Speak Your Mind': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Barry M_Lip Paint_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Bbia 魅雅_謬斯女神完美唇膏_02': {'上色度': 1.3519,
#   '保濕度': -2.6197,
#   '持久度': 2.4658,
#   '推勻度': 2.9333,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 9.125,
#   '透亮度': -0.375,
#   '遮瑕度': 3.4125,
#   '顯色度': 8.3673,
#   '飽和度': 6.6406},
#  'Bbia 魅雅_謬斯女神完美唇膏_04': {'上色度': 1.3519,
#   '保濕度': -2.6197,
#   '持久度': 2.4658,
#   '推勻度': 2.9333,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 9.125,
#   '透亮度': -0.375,
#   '遮瑕度': 3.4125,
#   '顯色度': 8.3673,
#   '飽和度': 6.6406},
#  'Bbia 魅雅_謬斯女神完美唇膏_06': {'上色度': 1.3519,
#   '保濕度': -2.6197,
#   '持久度': 2.4658,
#   '推勻度': 2.9333,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 9.125,
#   '透亮度': -0.375,
#   '遮瑕度': 3.4125,
#   '顯色度': 8.3673,
#   '飽和度': 6.6406},
#  'Bbia 魅雅_謬斯女神完美唇膏_08': {'上色度': 1.3519,
#   '保濕度': -2.6197,
#   '持久度': 2.4658,
#   '推勻度': 2.9333,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 9.125,
#   '透亮度': -0.375,
#   '遮瑕度': 3.4125,
#   '顯色度': 8.3673,
#   '飽和度': 6.6406},
#  'Bbia 魅雅_謬斯女神完美唇膏_10': {'上色度': 1.3519,
#   '保濕度': -2.6197,
#   '持久度': 2.4658,
#   '推勻度': 2.9333,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 9.125,
#   '透亮度': -0.375,
#   '遮瑕度': 3.4125,
#   '顯色度': 8.3673,
#   '飽和度': 6.6406},
#  'Bbia 魅雅_金色玫瑰珍藏唇膏_02': {'上色度': -0.25,
#   '保濕度': 2.3936,
#   '持久度': 7.25,
#   '推勻度': 5.4,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 6.125,
#   '透亮度': 2.1429,
#   '遮瑕度': 4.25,
#   '顯色度': 8.25,
#   '飽和度': 6.8056},
#  'Bbia 魅雅_金色玫瑰珍藏唇膏_04': {'上色度': -0.25,
#   '保濕度': 2.3936,
#   '持久度': 7.25,
#   '推勻度': 5.4,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 6.125,
#   '透亮度': 2.1429,
#   '遮瑕度': 4.25,
#   '顯色度': 8.25,
#   '飽和度': 6.8056},
#  'BEAUTYMAKER_想你水吻唇膏 Rouge Hydrating Lip Color_1': {'上色度': -0.25,
#   '保濕度': 2.3936,
#   '持久度': 7.25,
#   '推勻度': 5.4,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 6.125,
#   '透亮度': 2.1429,
#   '遮瑕度': 4.25,
#   '顯色度': 8.25,
#   '飽和度': 6.8056},
#  'BEAUTYMAKER_想你水吻唇膏 Rouge Hydrating Lip Color_3': {'上色度': 0.0,
#   '保濕度': -3.9444,
#   '持久度': 0.0,
#   '推勻度': 4.0,
#   '清爽度': -0.125,
#   '種類': '唇膏',
#   '自然度': 4.625,
#   '透亮度': 5.3571,
#   '遮瑕度': 1.0312,
#   '顯色度': 8.4348,
#   '飽和度': 6.75},
#  'BEAUTYMAKER_想你水吻唇膏 Rouge Hydrating Lip Color_5': {'上色度': 0.0,
#   '保濕度': -3.9444,
#   '持久度': 0.0,
#   '推勻度': 4.0,
#   '清爽度': -0.125,
#   '種類': '唇膏',
#   '自然度': 4.625,
#   '透亮度': 5.3571,
#   '遮瑕度': 1.0312,
#   '顯色度': 8.4348,
#   '飽和度': 6.75},
#  'BEAUTYMAKER_水吻炫彩觸控唇膏_one_color': {'上色度': 0.0,
#   '保濕度': -3.9444,
#   '持久度': 0.0,
#   '推勻度': 4.0,
#   '清爽度': -0.125,
#   '種類': '唇膏',
#   '自然度': 4.625,
#   '透亮度': 5.3571,
#   '遮瑕度': 1.0312,
#   '顯色度': 8.4348,
#   '飽和度': 6.75},
#  'BEBE POSHE 奢華寶貝_寶石晨露雙芯唇彩_one_color': {'上色度': 1.7143,
#   '保濕度': 0.1176,
#   '持久度': 3.825,
#   '推勻度': 3.25,
#   '清爽度': 1.25,
#   '種類': '唇膏',
#   '自然度': 8.5086,
#   '透亮度': 6.1429,
#   '遮瑕度': 2.1875,
#   '顯色度': 4.0714,
#   '飽和度': -7.5},
#  'BECCA_Ultimate Matte Lip Colour_one_color': {'上色度': 0.0,
#   '保濕度': -2.619,
#   '持久度': 10.5,
#   '推勻度': -2.6667,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 1.75,
#   '透亮度': 6.0,
#   '遮瑕度': -0.375,
#   '顯色度': -4.0,
#   '飽和度': 0},
#  'BECCA_零妝感唇頰兩用粉霜 Lip And Cheek Creme_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Benefit_菲菲潤色唇膏 Lip Tint Hydrator_熱情菲菲': {'上色度': 0,
#   '保濕度': 4.1667,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Benefit_菲菲潤色唇膏 Lip Tint Hydrator_紅粉菲菲': {'上色度': 2.0,
#   '保濕度': 1.6667,
#   '持久度': 0.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 7.5,
#   '遮瑕度': -0.75,
#   '顯色度': -2.0,
#   '飽和度': 5.0},
#  'BITE BEAUTY_Luminous Creme Lipstick_one_color': {'上色度': 2.0,
#   '保濕度': 1.6667,
#   '持久度': 0.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 7.5,
#   '遮瑕度': -0.75,
#   '顯色度': -2.0,
#   '飽和度': 5.0},
#  'BOBBI BROWN 芭比波朗_悅虹唇膏 Lip Color_one_color': {'上色度': 0,
#   '保濕度': 15.0,
#   '持久度': 11.25,
#   '推勻度': -2.6667,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 9.75,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_潤澤啞色唇膏_CALYPSO': {'上色度': 2.0,
#   '保濕度': -1.5,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 6.0,
#   '遮瑕度': 6.0,
#   '顯色度': 14.0,
#   '飽和度': 5.0},
#  'BOBBI BROWN 芭比波朗_潤澤啞色唇膏_HOT': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_潤澤啞色唇膏_PALE PEACH': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_潤澤啞色唇膏_RED CARPET': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_潤澤啞色唇膏_TRUE PINK': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_潤采唇膏 Creamy Lip Color_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_02 Berry Shimmer 紅莓': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_04 Ruby Shimmer酒紅    ': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_06 Twilight Shimmer 褐棕 ': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_08 Beige Gold Shimmer 燦金': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_10 Calypso Shimmer 粉橘': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_真珠光潤唇膏 High Shimmer Lip Color_12 Ballerina Shimmer 芭蕾': {'上色度': -0.5,
#   '保濕度': 3.25,
#   '持久度': -1.4062,
#   '推勻度': 0.75,
#   '清爽度': 1.2917,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 5.7857,
#   '遮瑕度': 6.75,
#   '顯色度': -1.3333,
#   '飽和度': 2.5},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_02': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_04': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_07': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_09': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_11': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_13': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_15': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_18': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color_20': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color__NEW_ Bobbi裸粉2017夏季': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color__NEW_ Italian Rose義式玫瑰2017夏季': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_精萃修護唇膏 Nourishing Lip Color__NEW_ Pink Rose暖玫紅2017夏季': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_絕色輕唇膏 Rich Lip Color SPF12_one_color': {'上色度': 0.8667,
#   '保濕度': 5.5696,
#   '持久度': 8.2174,
#   '推勻度': -1.0,
#   '清爽度': 0.8125,
#   '種類': '唇膏',
#   '自然度': 5.3958,
#   '透亮度': 5.6143,
#   '遮瑕度': 1.425,
#   '顯色度': 9.0,
#   '飽和度': 1.25},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_02 Hot Raspberry瑩粉紅': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_04 Pink Blossom 亮桃紅': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_06 Cherry Pink 櫻桃': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_08 Black Plum 紫梅': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_10 Carolina深玫紅': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_12 Melba 甜粉紅': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_14 Tutu 紗澄': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_19 夏日裸限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_21 糖粉紅限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_Boho Bronze 波西米亞限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_Peach Sorbet 杏桃冰沙限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_Pink Gold 陽光輕吻限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_絲緞光修護唇膏 Sheer Lip Color_Pink Rose薔薇限量': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_繽紛唇頰霜 Pot Rouge_one_color': {'上色度': 0,
#   '保濕度': 4.5833,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 13.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Bright Raspberry紅莓': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Cassis甜酒紅': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Dusty Pink 粉紅': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Electric Pink桃紅': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Hot Berry艷莓限量': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Hot Pink熱粉限量': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Rich Nude暖膚限量': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_藝術家唇色筆_Sunset Orange日落': {'上色度': 3.5,
#   '保濕度': 0.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ BABE來吧寶貝': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ BARE暗戀情人': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ BLACKBERRY性感惡魔': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ CALI ROSE仙女下凡': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ CRANBERRY溫柔難忘': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ CRUSH一見鍾情': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ PLUM魂牽夢縈': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ REGAL無法抵抗': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ SUNSET熱情如火': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_迷戀輕吻唇膏 Crushed Lip Color__NEW_ WATERMELON陽光寶貝': {'上色度': 2.5,
#   '保濕度': -3.75,
#   '持久度': -9.0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.25,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_ 義式誘惑': {'上色度': 0,
#   '保濕度': -2.5,
#   '持久度': 9.0,
#   '推勻度': -6.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 12.25,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_低調玫瑰': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_午夜曼哈頓': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_天鵝絨': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_完美裸唇限量2016 聖誕彩妝': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_巴黎女人': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_復古女伶': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_性感玫瑰': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_情迷巴拿馬': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_摩登裸妝': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_春日花漾': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_極致烈焰': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_玫瑰紅': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_皇家紅潮限量2017春季彩妝': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_粉紅棉花糖': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_粉紅石榴汁': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_粉色牛皮': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_紫李白蘭地': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_芭比裸唇限量2016夏季彩妝': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_莓果慕斯': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_蜜桃氣泡酒': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_金緻奢華唇膏_覆盆莓塔': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_限量金緻唇膏 Lip Color_Beige Gold Shimmer香檳金限量': {'上色度': 2.0357,
#   '保濕度': 3.6082,
#   '持久度': 6.3,
#   '推勻度': 0.0,
#   '清爽度': 0.6667,
#   '種類': '唇膏',
#   '自然度': 10.0625,
#   '透亮度': 4.6,
#   '遮瑕度': 2.4643,
#   '顯色度': 10.0,
#   '飽和度': 5.625},
#  'BOBBI BROWN 芭比波朗_限量金緻唇膏 Lip Color_Malt Shimmer裸麥金限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'bonbon_スティックグロスSPF20PA++_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Boots 博姿_新穎唇膏 Colour Renew Lipstick_one_color': {'上色度': 0,
#   '保濕度': 17.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Boots 博姿_芳澤唇膏 Pure Colour Lipstick_one_color': {'上色度': 2.0,
#   '保濕度': 15.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 12.25,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Botanic farm_컬러풀 드로잉매트 립스틱 Colorful Drawing Matte Lipstick _one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_BR02': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_OR02': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_OR04': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_PK02': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_PK04': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_植物樂園玫瑰花開瑩潤唇膏_RD01': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'Botanic farm_童話樂園晶潤雙色唇膏_one_color': {'上色度': -3.0,
#   '保濕度': 10.7143,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': 10.6667,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_ 戀法魔幻經典唇膏_#39 摩卡玫瑰': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_ 戀法魔幻經典唇膏_#46勃根地紅': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_12小時戀法魔幻經典唇膏_33': {'上色度': -1.75,
#   '保濕度': 2.125,
#   '持久度': 1.125,
#   '推勻度': 7.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -3.5,
#   '遮瑕度': 3.0,
#   '顯色度': 5.25,
#   '飽和度': 7.5},
#  'BOURJOIS 妙巴黎_12小時戀法魔幻經典唇膏_44': {'上色度': -1.75,
#   '保濕度': 2.125,
#   '持久度': 1.125,
#   '推勻度': 7.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -3.5,
#   '遮瑕度': 3.0,
#   '顯色度': 5.25,
#   '飽和度': 7.5},
#  'BOURJOIS 妙巴黎_12小時戀法魔幻經典唇膏_46': {'上色度': -1.75,
#   '保濕度': 2.125,
#   '持久度': 1.125,
#   '推勻度': 7.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -3.5,
#   '遮瑕度': 3.0,
#   '顯色度': 5.25,
#   '飽和度': 7.5},
#  'BOURJOIS 妙巴黎_一代尤霧絲柔唇霜 So D_eacute_licate Lipcream_one_color': {'上色度': -1.75,
#   '保濕度': 2.125,
#   '持久度': 1.125,
#   '推勻度': 7.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -3.5,
#   '遮瑕度': 3.0,
#   '顯色度': 5.25,
#   '飽和度': 7.5},
#  'BOURJOIS 妙巴黎_戀法魔幻紅唇_03': {'上色度': 0.5,
#   '保濕度': 5.0,
#   '持久度': 5.4643,
#   '推勻度': 4.6,
#   '清爽度': 1.45,
#   '種類': '唇膏',
#   '自然度': 10.5,
#   '透亮度': 1.2,
#   '遮瑕度': 1.75,
#   '顯色度': 8.7059,
#   '飽和度': 6.875},
#  'BOURJOIS 妙巴黎_戀法魔幻紅唇_05': {'上色度': 0.3077,
#   '保濕度': 0.9813,
#   '持久度': 4.125,
#   '推勻度': -1.6,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.4219,
#   '透亮度': 3.6818,
#   '遮瑕度': 2.3813,
#   '顯色度': 7.4217,
#   '飽和度': 5.2083},
#  'BOURJOIS 妙巴黎_戀法魔幻紅唇_10': {'上色度': 0.3077,
#   '保濕度': 0.9813,
#   '持久度': 4.125,
#   '推勻度': -1.6,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.4219,
#   '透亮度': 3.6818,
#   '遮瑕度': 2.3813,
#   '顯色度': 7.4217,
#   '飽和度': 5.2083},
#  'BOURJOIS 妙巴黎_戀法魔幻紅唇_12': {'上色度': 0.3077,
#   '保濕度': 0.9813,
#   '持久度': 4.125,
#   '推勻度': -1.6,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.4219,
#   '透亮度': 3.6818,
#   '遮瑕度': 2.3813,
#   '顯色度': 7.4217,
#   '飽和度': 5.2083},
#  'BOURJOIS 妙巴黎_戀法魔幻紅唇_17': {'上色度': 0.3077,
#   '保濕度': 0.9813,
#   '持久度': 4.125,
#   '推勻度': -1.6,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.4219,
#   '透亮度': 3.6818,
#   '遮瑕度': 2.3813,
#   '顯色度': 7.4217,
#   '飽和度': 5.2083},
#  'BOURJOIS 妙巴黎_水吻多情唇膏 Docteur Glamour_one_color': {'上色度': 0.3077,
#   '保濕度': 0.9813,
#   '持久度': 4.125,
#   '推勻度': -1.6,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.4219,
#   '透亮度': 3.6818,
#   '遮瑕度': 2.3813,
#   '顯色度': 7.4217,
#   '飽和度': 5.2083},
#  'BOURJOIS 妙巴黎_炫色晶凝唇膏─水潤炫亮系列 Sweet Kiss Shine_one_color': {'上色度': 0.8333,
#   '保濕度': 1.6667,
#   '持久度': 1.2656,
#   '推勻度': 2.6,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 2.7222,
#   '透亮度': 6.0,
#   '遮瑕度': 1.875,
#   '顯色度': 8.4706,
#   '飽和度': 5.5},
#  'BOURJOIS 妙巴黎_珠光寶貝唇膏 LOVELY ROUGE_one_color': {'上色度': -0.5,
#   '保濕度': -3.3824,
#   '持久度': 4.7812,
#   '推勻度': 4.0,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 8.75,
#   '透亮度': 6.0,
#   '遮瑕度': 4.125,
#   '顯色度': 12.4,
#   '飽和度': 5.0},
#  'BOURJOIS 妙巴黎_迷力唇電筒 mini lipstick_one_color': {'上色度': 0.875,
#   '保濕度': 5.4545,
#   '持久度': 1.35,
#   '推勻度': -2.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 8.5312,
#   '透亮度': 8.3571,
#   '遮瑕度': 3.125,
#   '顯色度': 2.1333,
#   '飽和度': 4.7917},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Blush No77緋紅 77 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Bright Plum No101亮梅紅 101 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Coral Pink No65珊瑚粉紅 65 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Devon Sunset No61德文郡夕陽色 61 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Garnet No81榴石色 81 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Light Crimson No49淺洋紅 49 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Nude Beige No01裸米色 01 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Nude No21裸色 21 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Oxblood No97大不列顛紅 97 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Pink Peony No37粉牡丹色 37 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Poppy Red No105罌粟紅 105 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Rose Pink No33玫瑰粉紅 33 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Sepia No85深褐色 85 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_Union Red No113英倫紅 113 號': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_BURBERRY KISSES唇膏 BURBERRY KISSES_節慶金120限量': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_Full Kisses唇膏_one_color': {'上色度': 2.0,
#   '保濕度': 11.0714,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0.6,
#   '遮瑕度': -4.5,
#   '顯色度': 2.0,
#   '飽和度': 5.8333},
#  'BURBERRY_絲柔亮彩唇膏_No2 PinkPeony': {'上色度': 0,
#   '保濕度': 6.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 16.0,
#   '飽和度': 0},
#  'BURBERRY_絲柔光感唇膏 Lip Cover_one_color': {'上色度': 0,
#   '保濕度': 6.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 16.0,
#   '飽和度': 0},
#  'BURBERRY_絲絨唇膏_one_color': {'上色度': 1.8,
#   '保濕度': 3.5656,
#   '持久度': 2.1375,
#   '推勻度': -5.75,
#   '清爽度': 1.5,
#   '種類': '唇膏',
#   '自然度': 8.8594,
#   '透亮度': 4.5577,
#   '遮瑕度': 1.5577,
#   '顯色度': 5.7143,
#   '飽和度': 8.4375},
#  'BURT`S BEES 小蜜蜂爺爺_啵啵粉彩筆 Lip Crayons_one_color': {'上色度': 0,
#   '保濕度': 3.125,
#   '持久度': 0,
#   '推勻度': 6.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': -0.875,
#   '透亮度': 7.5,
#   '遮瑕度': -4.5,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BURT`S BEES 小蜜蜂爺爺_摩登好漾彩唇膏 Lipstick_one_color': {'上色度': 3.5,
#   '保濕度': 3.9726,
#   '持久度': 6.5455,
#   '推勻度': 5.0,
#   '清爽度': 0.0,
#   '種類': '唇膏',
#   '自然度': 7.4257,
#   '透亮度': 1.9091,
#   '遮瑕度': -0.9375,
#   '顯色度': 2.5625,
#   '飽和度': 7.0833},
#  'butter LONDON_LIPPY唇膏 LIPPY Tinted Balm_不良少年Teddy Boy': {'上色度': -0.5,
#   '保濕度': -1.6912,
#   '持久度': 7.65,
#   '推勻度': 1.6667,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 5.9792,
#   '透亮度': 2.1,
#   '遮瑕度': 0,
#   '顯色度': 7.1429,
#   '飽和度': 0},
#  'butter LONDON_LIPPY唇膏 LIPPY Tinted Balm_吻Axis Kiss': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_LIPPY唇膏 LIPPY Tinted Balm_杏黃光線Apricot Sunray': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_LIPPY唇膏 LIPPY Tinted Balm_狂人Nutter': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_LIPPY唇膏 LIPPY Tinted Balm_酒紅黑莓Black Cherry': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_豐吻豔色唇膏_Daring-無所畏': {'上色度': 0.5,
#   '保濕度': 1.3889,
#   '持久度': 2.61,
#   '推勻度': -1.0,
#   '清爽度': 1.3333,
#   '種類': '唇膏',
#   '自然度': -4.8125,
#   '透亮度': 0.6,
#   '遮瑕度': 4.5,
#   '顯色度': 8.2857,
#   '飽和度': -1.25},
#  'butter LONDON_豐吻豔色唇膏_Elated得意洋洋': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_豐吻豔色唇膏_Impulsive一時衝動': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butter LONDON_豐吻豔色唇膏_Provocative火熱小辣椒': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_Cream Lipstick_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_Sheer Lipstick_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_16 –桃紅玫瑰限量': {'上色度': 3.5,
#   '保濕度': 10.4167,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 12.25,
#   '透亮度': 6.0,
#   '遮瑕度': 3.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_18 –夏日迷情限量': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°11致命吸引': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°13桑格里誘惑': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°15香醇美酒': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°2情挑探戈': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°4玫瑰公主': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°6派對謬斯': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透水潤唇膏_N°8珊瑚紅': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 8.0,
#   '遮瑕度': -0.75,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_光透裸色唇膏_No1 Bare balm': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 18.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
# ...
#   '飽和度': 6.6406},
#  'MAC_零色差唇膏_Postmodern': {'上色度': 2.0,
#   '保濕度': 0.3431,
#   '持久度': 1.8214,
#   '推勻度': 3.2,
#   '清爽度': -0.25,
#   '種類': '唇膏',
#   '自然度': 10.5,
#   '透亮度': 7.8,
#   '遮瑕度': 2.6786,
#   '顯色度': 7.2381,
#   '飽和度': 6.6406},
#  'MAC_零色差唇膏_Stallion': {'上色度': 2.0,
#   '保濕度': 0.3431,
#   '持久度': 1.8214,
#   '推勻度': 3.2,
#   '清爽度': -0.25,
#   '種類': '唇膏',
#   '自然度': 10.5,
#   '透亮度': 7.8,
#   '遮瑕度': 2.6786,
#   '顯色度': 7.2381,
#   '飽和度': 6.6406},
#  'MAC_霧幻性感唇膏 MATTENE LIPSTICK_one_color': {'上色度': 2.0,
#   '保濕度': 0.3431,
#   '持久度': 1.8214,
#   '推勻度': 3.2,
#   '清爽度': -0.25,
#   '種類': '唇膏',
#   '自然度': 10.5,
#   '透亮度': 7.8,
#   '遮瑕度': 2.6786,
#   '顯色度': 7.2381,
#   '飽和度': 6.6406},
#  'MADINA 瑪丁娜_絕色光唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MAKE UP FOR EVER_口紅 Lip Stick_one_color': {'上色度': 3.0,
#   '保濕度': 2.3214,
#   '持久度': -2.8125,
#   '推勻度': 4.0,
#   '清爽度': 0.7,
#   '種類': '唇膏',
#   '自然度': 9.5,
#   '透亮度': 5.5,
#   '遮瑕度': -4.5,
#   '顯色度': 11.1667,
#   '飽和度': 0},
#  'MAKE UP FOR EVER_吻色唇膏_珍珠粉銅限量': {'上色度': 0,
#   '保濕度': -12.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 6.0,
#   '遮瑕度': 0,
#   '顯色度': 8.0,
#   '飽和度': 11.25},
#  'MAKE UP FOR EVER_烈吻色唇膏 Rouge Artist Intense_one_color': {'上色度': 0,
#   '保濕度': -7.2727,
#   '持久度': 7.65,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 15.75,
#   '透亮度': 6.0,
#   '遮瑕度': 3.0,
#   '顯色度': 10.0,
#   '飽和度': 1.6667},
#  'MAKE UP FOR EVER_藝術大師玩色唇膏-柔光 ARTIST ROUGE CREME_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Marc Jacobs_Lovemarc-Lip Gel_one_color': {'上色度': 0.3,
#   '保濕度': -3.25,
#   '持久度': -3.2143,
#   '推勻度': 4.0,
#   '清爽度': -0.25,
#   '種類': '唇膏',
#   '自然度': 7.7,
#   '透亮度': 7.0,
#   '遮瑕度': -0.75,
#   '顯色度': 4.2,
#   '飽和度': 6.5},
#  'MARY KAY 玫琳凱_愛心義賣唇膏-粉紅力量_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MARY KAY 玫琳凱_流光潤采唇膏_one_color': {'上色度': 0,
#   '保濕度': -3.3333,
#   '持久度': 10.125,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 14.0,
#   '飽和度': 0},
#  'Maryquant 瑪莉官_MQ組合口紅片_one_color': {'上色度': 0,
#   '保濕度': 17.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 5.25,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maxfactor 蜜絲佛陀_柔美潤澤唇膏 Colour Elixir lipstick_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maxfactor 蜜絲佛陀_水漾綻動唇膏_one_color': {'上色度': 0,
#   '保濕度': 11.7188,
#   '持久度': 5.625,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': -9.0,
#   '遮瑕度': 3.0,
#   '顯色度': 9.0,
#   '飽和度': 6.875},
#  'Maxfactor 蜜絲佛陀_躍動彩澤雙色唇膏_one_color': {'上色度': 0,
#   '保濕度': 15.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 11.375,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maxfactor 蜜絲佛陀_鎖色水凝唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_24超持色水感液態唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_好氣色CC輕唇膏升級版_BB01': {'上色度': 0,
#   '保濕度': -10.0,
#   '持久度': 0,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 10.0,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_好氣色CC輕唇膏升級版_OR01': {'上色度': 1.2045,
#   '保濕度': 6.9456,
#   '持久度': -0.75,
#   '推勻度': 2.5714,
#   '清爽度': 0.5238,
#   '種類': '唇膏',
#   '自然度': 6.0533,
#   '透亮度': 5.3382,
#   '遮瑕度': 2.3942,
#   '顯色度': 5.0233,
#   '飽和度': 2.6014},
#  'MAYBELLINE 媚比琳_好氣色CC輕唇膏升級版_PK02': {'上色度': 1.2045,
#   '保濕度': 6.9456,
#   '持久度': -0.75,
#   '推勻度': 2.5714,
#   '清爽度': 0.5238,
#   '種類': '唇膏',
#   '自然度': 6.0533,
#   '透亮度': 5.3382,
#   '遮瑕度': 2.3942,
#   '顯色度': 5.0233,
#   '飽和度': 2.6014},
#  'MAYBELLINE 媚比琳_好氣色CC輕唇膏升級版_PK04': {'上色度': 1.2045,
#   '保濕度': 6.9456,
#   '持久度': -0.75,
#   '推勻度': 2.5714,
#   '清爽度': 0.5238,
#   '種類': '唇膏',
#   '自然度': 6.0533,
#   '透亮度': 5.3382,
#   '遮瑕度': 2.3942,
#   '顯色度': 5.0233,
#   '飽和度': 2.6014},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_OR01': {'上色度': 1.2045,
#   '保濕度': 6.9456,
#   '持久度': -0.75,
#   '推勻度': 2.5714,
#   '清爽度': 0.5238,
#   '種類': '唇膏',
#   '自然度': 6.0533,
#   '透亮度': 5.3382,
#   '遮瑕度': 2.3942,
#   '顯色度': 5.0233,
#   '飽和度': 2.6014},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_PK02': {'上色度': 1.0635,
#   '保濕度': 4.05,
#   '持久度': 1.6588,
#   '推勻度': 2.4857,
#   '清爽度': 1.0312,
#   '種類': '唇膏',
#   '自然度': 6.8697,
#   '透亮度': 6.3519,
#   '遮瑕度': 0.4412,
#   '顯色度': 6.2629,
#   '飽和度': 3.3152},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_RD02': {'上色度': 1.0635,
#   '保濕度': 4.05,
#   '持久度': 1.6588,
#   '推勻度': 2.4857,
#   '清爽度': 1.0312,
#   '種類': '唇膏',
#   '自然度': 6.8697,
#   '透亮度': 6.3519,
#   '遮瑕度': 0.4412,
#   '顯色度': 6.2629,
#   '飽和度': 3.3152},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_S BK01': {'上色度': 1.0635,
#   '保濕度': 4.05,
#   '持久度': 1.6588,
#   '推勻度': 2.4857,
#   '清爽度': 1.0312,
#   '種類': '唇膏',
#   '自然度': 6.8697,
#   '透亮度': 6.3519,
#   '遮瑕度': 0.4412,
#   '顯色度': 6.2629,
#   '飽和度': 3.3152},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_S OR01': {'上色度': 1.0635,
#   '保濕度': 4.05,
#   '持久度': 1.6588,
#   '推勻度': 2.4857,
#   '清爽度': 1.0312,
#   '種類': '唇膏',
#   '自然度': 6.8697,
#   '透亮度': 6.3519,
#   '遮瑕度': 0.4412,
#   '顯色度': 6.2629,
#   '飽和度': 3.3152},
#  'MAYBELLINE 媚比琳_好氣色漸層三色CC輕唇膏_S WH01': {'上色度': 1.0635,
#   '保濕度': 4.05,
#   '持久度': 1.6588,
#   '推勻度': 2.4857,
#   '清爽度': 1.0312,
#   '種類': '唇膏',
#   '自然度': 6.8697,
#   '透亮度': 6.3519,
#   '遮瑕度': 0.4412,
#   '顯色度': 6.2629,
#   '飽和度': 3.3152},
#  'MAYBELLINE 媚比琳_好氣色貝殼霓光漸層唇膏_04人魚粉紫': {'上色度': 0.8409,
#   '保濕度': 2.6093,
#   '持久度': 0.7634,
#   '推勻度': 1.64,
#   '清爽度': 0.9375,
#   '種類': '唇膏',
#   '自然度': 7.5,
#   '透亮度': 5.8099,
#   '遮瑕度': 2.2125,
#   '顯色度': 5.0,
#   '飽和度': 7.2656},
#  'MAYBELLINE 媚比琳_好氣色貝殼霓光漸層唇膏_10紅酒派對': {'上色度': 0.8409,
#   '保濕度': 2.6093,
#   '持久度': 0.7634,
#   '推勻度': 1.64,
#   '清爽度': 0.9375,
#   '種類': '唇膏',
#   '自然度': 7.5,
#   '透亮度': 5.8099,
#   '遮瑕度': 2.2125,
#   '顯色度': 5.0,
#   '飽和度': 7.2656},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏__NEW_ 焦糖拿鐵': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_名媛粉': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_性感桃': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_杏桃裸': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_櫻花粉': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_焦糖裸': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_玫瑰紅': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_石榴紅': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_經典紅': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色柔霧花蜜唇膏_鮭魚粉': {'上色度': 0.9432,
#   '保濕度': -2.4049,
#   '持久度': 3.3307,
#   '推勻度': 2.3902,
#   '清爽度': -0.0909,
#   '種類': '唇膏',
#   '自然度': 9.4659,
#   '透亮度': 1.9655,
#   '遮瑕度': 2.94,
#   '顯色度': 7.2782,
#   '飽和度': 5.0},
#  'MAYBELLINE 媚比琳_極綻色烈焰放肆絲絨霧光唇膏_one_color': {'上色度': 1.625,
#   '保濕度': 2.7841,
#   '持久度': -1.0227,
#   '推勻度': 3.3333,
#   '清爽度': -0.25,
#   '種類': '唇膏',
#   '自然度': 5.9792,
#   '透亮度': 6.5357,
#   '遮瑕度': 1.125,
#   '顯色度': 6.6,
#   '飽和度': 2.9167},
#  'MAYBELLINE 媚比琳_極綻色絲潤柔霧唇膏 _MAT2': {'上色度': 2.0,
#   '保濕度': 6.4583,
#   '持久度': 3.5357,
#   '推勻度': 1.75,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': -12.25,
#   '透亮度': 9.75,
#   '遮瑕度': 3.0,
#   '顯色度': 8.8571,
#   '飽和度': 8.4375},
#  'MAYBELLINE 媚比琳_極綻色絲潤柔霧唇膏 _MAT4': {'上色度': 0,
#   '保濕度': 0.4268,
#   '持久度': -1.0588,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 4.6667,
#   '透亮度': -1.5,
#   '遮瑕度': 4.125,
#   '顯色度': 6.9333,
#   '飽和度': 7.5},
#  'MAYBELLINE 媚比琳_極綻色絲絨霧光唇膏__NEW_ 罌粟紫莓': {'上色度': 0,
#   '保濕度': 0.4268,
#   '持久度': -1.0588,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 4.6667,
#   '透亮度': -1.5,
#   '遮瑕度': 4.125,
#   '顯色度': 6.9333,
#   '飽和度': 7.5},
#  'MAYBELLINE 媚比琳_極綻色絲絨霧光唇膏__NEW_ 西柚磚紅': {'上色度': 2.2727,
#   '保濕度': -3.0063,
#   '持久度': 2.43,
#   '推勻度': 3.4,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 11.9318,
#   '透亮度': 4.5,
#   '遮瑕度': 2.0312,
#   '顯色度': 8.8333,
#   '飽和度': 5.75},
#  'MAYBELLINE 媚比琳_極綻色花漾革命保濕唇膏_REB02': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_極綻色花漾革命保濕唇膏_REB04': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_極綻色花漾革命保濕唇膏_REB06 ': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_極綻色花漾革命保濕唇膏_REB08': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_極綻色花漾革命保濕唇膏_REB10': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_水誘光唇膏 Water Shine Lipstick Pure Reno_one_color': {'上色度': 0.9808,
#   '保濕度': 5.377,
#   '持久度': 3.4737,
#   '推勻度': 2.2903,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 8.0132,
#   '透亮度': 5.8448,
#   '遮瑕度': 2.6471,
#   '顯色度': 7.8,
#   '飽和度': 7.2857},
#  'MAYBELLINE 媚比琳_裸放悸動絲絨霧光唇膏_MAT1': {'上色度': 0,
#   '保濕度': 17.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 1.0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_裸放悸動絲絨霧光唇膏_MAT3': {'上色度': 0.9655,
#   '保濕度': -2.7165,
#   '持久度': 3.3538,
#   '推勻度': 3.1111,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 5.9915,
#   '透亮度': 3.3333,
#   '遮瑕度': 2.8594,
#   '顯色度': 7.6825,
#   '飽和度': 3.5714},
#  'MAYBELLINE 媚比琳_裸放悸動絲絨霧光唇膏_MAT5': {'上色度': 0.9655,
#   '保濕度': -2.7165,
#   '持久度': 3.3538,
#   '推勻度': 3.1111,
#   '清爽度': 0.5,
#   '種類': '唇膏',
#   '自然度': 5.9915,
#   '透亮度': 3.3333,
#   '遮瑕度': 2.8594,
#   '顯色度': 7.6825,
#   '飽和度': 3.5714},
#  'Mdmmd 明洞國際_綺幻光霓彩棉花糖_one_color': {'上色度': 0,
#   '保濕度': 0.5556,
#   '持久度': 0.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 13.3333,
#   '飽和度': 8.75},
#  'media 媚點_滋潤持久型唇膏_one_color': {'上色度': 0.9167,
#   '保濕度': 4.1869,
#   '持久度': 2.8443,
#   '推勻度': 2.92,
#   '清爽度': 0.8333,
#   '種類': '唇膏',
#   '自然度': 6.5917,
#   '透亮度': 6.0417,
#   '遮瑕度': 0.9375,
#   '顯色度': 4.4299,
#   '飽和度': 2.0588},
#  'Melaleuca 美樂家_潤澤護色唇膏 Perfecting Lip Treatment_one_color': {'上色度': 4.5,
#   '保濕度': 5.0,
#   '持久度': 2.25,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 4.0833,
#   '透亮度': -9.75,
#   '遮瑕度': 1.75,
#   '顯色度': 8.0,
#   '飽和度': 0},
#  'MENARD 美伊娜多_JUPIER自動唇膏G_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'mfc_艷蜜唇膏_one_color': {'上色度': 0,
#   '保濕度': -4.375,
#   '持久度': 11.25,
#   '推勻度': 4.0,
#   '清爽度': -1.0,
#   '種類': '唇膏',
#   '自然度': 7.0,
#   '透亮度': 10.5,
#   '遮瑕度': 0,
#   '顯色度': -12.0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_BE005': {'上色度': 3.5,
#   '保濕度': 16.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': -12.0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_OR004': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_PK013': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_PK033': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_PK053': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_PK073': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_RD001': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_RD021': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_RS002': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_RS022': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MIKIMOTO 御木本_珍珠光唇膏_RS051': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Milani_COLOR STATEMENT® LIPSTICK_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MISASA 美爽爽_柔光唇膏_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MISASA 美爽爽_絲絨恆久唇膏_one_color': {'上色度': 0,
#   '保濕度': 4.1667,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Miss Hana 花娜小姐_三色立體唇膏_RD01': {'上色度': 2.125,
#   '保濕度': 4.2105,
#   '持久度': 0.0,
#   '推勻度': 4.1429,
#   '清爽度': 0.5833,
#   '種類': '唇膏',
#   '自然度': 7.9872,
#   '透亮度': 5.5588,
#   '遮瑕度': 1.26,
#   '顯色度': 4.6364,
#   '飽和度': 6.875},
#  'Miss Hana 花娜小姐_凍色嫩唇修護蠟_one_color': {'上色度': 2.125,
#   '保濕度': 4.2105,
#   '持久度': 0.0,
#   '推勻度': 4.1429,
#   '清爽度': 0.5833,
#   '種類': '唇膏',
#   '自然度': 7.9872,
#   '透亮度': 5.5588,
#   '遮瑕度': 1.26,
#   '顯色度': 4.6364,
#   '飽和度': 6.875},
#  'Miss Hana 花娜小姐_雙頭持久唇露豐潤唇膏_02展現自我': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 15.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MISSHA_Creamy matte lip rouge_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 15.75,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MISSHA_柔潤啞緻唇膏 MISSHA M Matt Lip Rouge SPF17_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 0,
#   '遮瑕度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MISSHA_格蘭迷炫璀璨唇膏_CR04': {'上色度': 3.6667,
#   '保濕度': -2.3611,
#   '持久度': 11.25,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': -10.5,
#   '透亮度': 6.0,
#   '遮瑕度': -4.5,
#   '顯色度': 11.6667,
#   '飽和度': 6.25},
#  'MISSHA_水漾亮澤原色潤唇膏_one_color': {'上色度': 3.6667,
#   '保濕度': -2.3611,
#   '持久度': 11.25,
#   '推勻度': 4.0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': -10.5,
#   '透亮度': 6.0,
#   '遮瑕度': -4.5,
#   '顯色度': 11.6667,
#   '飽和度': 6.25},
#  'MISSHA_水潤唇膏 Missha Flower Glossy Lipstick_one_color': {'上色度': 0,
#   '保濕度': 15.0,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 0,
#   '透亮度': 6.0,
#   '遮瑕度': 3.0,
#   '顯色度': -11.0,
#   '飽和度': 8.75},
#  'MISSHA_熊大霧感胭脂唇膏SPF13_one_color': {'上色度': 0,
#   '保濕度': -4.1667,
#   '持久度': -3.0,
#   '推勻度': 5.5,
#   '清爽度': 0,
#   '種類': '唇膏',
#   '自然度': 11.25,
#   '透亮度': 8.25,
#   '遮瑕度': 3.75,
#   '顯色度': 10.5,
#   '飽和度': 5.0},
#  ...}

# %%
# 保濕,持久,顯色,自然,透亮,飽和,推勻,遮,上色,黏膩    
#print(deny)
#print(deny2)
#print(deny3)
#print(good1)
#print(good2)
# print(mainLong1)
# print(mainShort)
# print(mainShort1)
print(cover)
print(cover1)

dic
# Out:
# 1.5

# %%
#             if '無法' in i :
#                 score=-1.75
#                 Tscore+=score
#                 deny.append(i)

#             elif '沒有' in i :
#                 score=-1.5
#                 Tscore+=score
#                 deny2.append(i)
#             elif '不易' in i :
#                 score=-1.25
#                 Tscore+=score
#                 deny3.append(i)
#             elif '非常' in i :
#                 score=2.25
#                 Tscore+=score
#                 good.append(i)
#             elif '超' in i :
#                 score=2
#                 Tscore+=score
#                 good1.append(i)
#             elif '很' in i :
#                 score=1.75
#                 Tscore+=score
#                 good2.append(i)
#             elif '更' in i :
#                 score=1.5
#                 Tscore+=score
#                 good3.append(i)
#             elif '小' in i :
#                 score=1.25
#                 Tscore+=score
#                 good4.append(i)
#             else:
#                 score=1
#                 Tscore+=score
#                 normal.append(i)
# Out:
# str

# %%
#眼線筆:暈開,上色,持久,顯色,飽和,推勻,透亮,保濕
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/眼線筆/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==(len(files)-1):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    while True:
        try:
            if test['comments']==[]:
                k+=1
                break
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)

            else:
                continue



        j+=1
        
    try:
        dic['防水度']=round((Waterpro1-UnWaterpro1)*8/len(Waterpro+UnWaterpro),4)
    except ZeroDivisionError:
        dic['防水度']=0
    try:
        dic['上色度']=round((EasytoCo1)*7/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['上色度']=0
        
    try:
        dic['持久度']=round((mainLong1-mainShort1)*6/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['持久度']=0
    try:
        dic['顯色度']=round((ShowColor1)*5/len(ShowColor),4)
    except ZeroDivisionError:
        dic['顯色度']=0
    try:
        dic['飽和度']=round((ColorSaturation1)*4/len(ColorSaturation),4)
    except ZeroDivisionError:
        dic['飽和度']=0    
    try:
        dic['推勻度']=round((blendout1-Unblendout1)*3/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['推勻度']=0
    try:
        dic['透亮度']=round((Bright1)*2/len(Bright),4)
    except ZeroDivisionError:
        dic['透亮度']=0    
    
    try:
        dic['保濕度']=round((Water1-Dry1)*1/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['保濕度']=0

    dic['種類']='眼線筆'
    dic[product_ID]=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/Score/Eyeliner_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product
# Out:
# {'3 Concept Eyes_creamy water proof eye liner_one_color': {'上色度': 6.25,
#   '保濕度': -0.5,
#   '持久度': 8.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.45,
#   '顯色度': 6.25,
#   '飽和度': 1.6667},
#  'ADDICTION 奧可玹_アイライナー ペンシル EYELINER PENCIL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'AKUMA_冰砂霧光眼彩筆_one_color': {'上色度': 5.6,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'AVANCE_絲滑眼線筆_深咖': {'上色度': 11.375,
#   '保濕度': -1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -15.3333,
#   '顯色度': 0,
#   '飽和度': 5.0},
#  'A_PIEU_抗暈眼線膠筆_BR01': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'A_PIEU_抗暈眼線膠筆_PK01': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Allcare 歐凱_Allcare歐凱 眼線筆_one_color': {'上色度': 6.4451,
#   '保濕度': -0.3125,
#   '持久度': 1.5,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.5385,
#   '顯色度': 5.5357,
#   '飽和度': -0.5},
#  'Angel Key_小惡魔防水眼線膠筆_one_color': {'上色度': 0.75,
#   '保濕度': -1.25,
#   '持久度': 8.25,
#   '推勻度': 3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -5.5556,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Avon 雅芳_色彩防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BCL_EX 2mm頑固眼線膠筆_one_color': {'上色度': 1.925,
#   '保濕度': -0.9167,
#   '持久度': -9.75,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.8095,
#   '顯色度': 6.875,
#   '飽和度': 0},
#  'BCL_戀愛速攻眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BEAUTYMAKER_晶漾大眼防水眼線筆 Crystal Eye Water Proof Eyelner_one_color': {'上色度': 1.75,
#   '保濕度': 0.125,
#   '持久度': 4.5,
#   '推勻度': -2.8125,
#   '種類': '眼線筆',
#   '透亮度': -3.0,
#   '防水度': -3.3793,
#   '顯色度': 5.9375,
#   '飽和度': 4.0},
#  'BEBE POSHE 奢華寶貝_WOW謎樣深邃光影雙效眼彩筆 WOW MYSTIQUE EYE TINT _ GEL LINER_極黑眼線膠筆／蜜糖金 眼影棒': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BEBE POSHE 奢華寶貝_WOW謎樣深邃光影雙效眼彩筆 WOW MYSTIQUE EYE TINT _ GEL LINER_自然棕眼線膠筆／玫瑰金 眼影棒': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BEBE POSHE 奢華寶貝_新魔幻晶燦防水眼線筆_one_color': {'上色度': 7.0,
#   '保濕度': -1.0,
#   '持久度': -3.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.2,
#   '顯色度': 8.75,
#   '飽和度': 4.0},
#  'BECCA_Line _ Define Pencil_one_color': {'上色度': 2.1875,
#   '保濕度': -0.125,
#   '持久度': 0,
#   '推勻度': -1.75,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 4.8571,
#   '顯色度': 7.0833,
#   '飽和度': 0},
#  'BOBBI BROWN 芭比波朗_流雲持久防水眼線膠筆 Long-Wear Eye Pencil_one_color': {'上色度': 3.9375,
#   '保濕度': -1.0,
#   '持久度': -6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.087,
#   '顯色度': 8.75,
#   '飽和度': 4.0},
#  'BOBBI BROWN 芭比波朗_瞬間煙燻眼線筆 _one_color': {'上色度': 9.625,
#   '保濕度': 0,
#   '持久度': 4.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 3.7895,
#   '顯色度': 6.6667,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_一筆勾炫眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_媚惑超模極黑眼線筆_one_color': {'上色度': 7.3957,
#   '保濕度': -0.3929,
#   '持久度': 4.6216,
#   '推勻度': 4.125,
#   '種類': '眼線筆',
#   '透亮度': 2.75,
#   '防水度': -2.6525,
#   '顯色度': 5.8333,
#   '飽和度': 5.2},
#  'BOURJOIS 妙巴黎_絕色雙嬌眼線筆_one_color': {'上色度': 6.125,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -11.5,
#   '顯色度': 7.5,
#   '飽和度': 0},
#  'BOURJOIS 妙巴黎_迷力眼線筆_one_color': {'上色度': 6.6172,
#   '保濕度': 1.0,
#   '持久度': 5.5,
#   '推勻度': -2.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -0.2258,
#   '顯色度': 6.6667,
#   '飽和度': 6.8},
#  'BOURJOIS 妙巴黎_閃閃仙女棒 Regard Effet Paillete_one_color': {'上色度': -0.875,
#   '保濕度': 1.5,
#   '持久度': -10.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.5,
#   '顯色度': 1.25,
#   '飽和度': 0},
#  'BURBERRY_絲柔深邃眼線筆_one_color': {'上色度': 5.95,
#   '保濕度': -0.25,
#   '持久度': 6.0,
#   '推勻度': 4.125,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.3333,
#   '顯色度': 5.0,
#   '飽和度': 2.6667},
#  'BURT`S BEES 小蜜蜂爺爺_眼線_眉兩用筆 Eyeliner _ Eyebrow Pencils_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_TERRYBLY晶碳防水眼線筆 CRAYON KHOL TERRYBLY_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'BY TERRY_煙燻眼墨筆 EYE POWDER-KAJAL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Barbie 芭比系列彩妝_24小時完美持久防水眼線筆_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 6.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'Bbia 魅雅_絕色完美防水眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Ben Nye_防水眼線筆 eye liner pencils_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Benefit_充電時刻亮眼筆_one_color': {'上色度': 7.0673,
#   '保濕度': -0.6875,
#   '持久度': 8.25,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.9091,
#   '顯色度': 0,
#   '飽和度': 3.3333},
#  'Benefit_壞女孩搶眼防水眼線筆_one_color': {'上色度': 9.8,
#   '保濕度': 0.8125,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -7.0909,
#   '顯色度': 6.875,
#   '飽和度': 4.0},
#  'Benefit_大開眼界防水眼線筆_one_color': {'上色度': 4.0833,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.1111,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'Benefit_白色精靈開眼筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Bloom_Eye Definer_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Boots 博姿_亮眸眼線彩 Eye Definer_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 13.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Boots 博姿_精緻眼線筆 Precision Eye Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CANMAKE_晶燦透亮眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CANMAKE_氈尖眼線筆 Quick Easy Eyeliner_one_color': {'上色度': 8.2727,
#   '保濕度': 0.0,
#   '持久度': 4.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.6667,
#   '顯色度': 11.25,
#   '飽和度': 4.0},
#  'CANMAKE_眼線筆 Eyeliner Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CANMAKE_纖幼眼線膏筆 Hyper Slim Gel Eyeliner_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CANMAKE_閃耀眼線筆 Sparkling Lame Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CANMAKE_防水眼線筆 Eyeliner Pencil_one_color': {'上色度': 4.9926,
#   '保濕度': -0.3571,
#   '持久度': 1.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.6857,
#   '顯色度': 0.8333,
#   '飽和度': 0},
#  'CEZANNE_防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CEZANNE_魅力眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CHANEL 香奈兒_精確眼線筆 Le Crayon Khol_one_color': {'上色度': 8.05,
#   '保濕度': -1.0,
#   '持久度': -0.5,
#   '推勻度': 6.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -5.4909,
#   '顯色度': -3.4375,
#   '飽和度': -1.0},
#  'CHIC CHOC 奇可俏可_俏女孩蕾絲眼線膠筆 CreamyPowderEyes_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CHIC CHOC 奇可俏可_星炫勻采筆 Shiny Eye Pencil_one_color': {'上色度': 7.9297,
#   '保濕度': 1.0,
#   '持久度': 2.5,
#   '推勻度': 3.5625,
#   '種類': '眼線筆',
#   '透亮度': -3.0,
#   '防水度': -7.3333,
#   '顯色度': 6.75,
#   '飽和度': 0},
#  'CHIC CHOC 奇可俏可_防水眼線筆_one_color': {'上色度': 9.5221,
#   '保濕度': 0.57,
#   '持久度': 1.4268,
#   '推勻度': 3.3,
#   '種類': '眼線筆',
#   '透亮度': 2.2353,
#   '防水度': -5.1159,
#   '顯色度': 7.1371,
#   '飽和度': 6.75},
#  'CHIC CHOC 奇可俏可_電眼星炫筆 Magical Shiny Eye Pencil_one_color': {'上色度': 7.875,
#   '保濕度': 1.5,
#   '持久度': -2.5,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 2.1875,
#   '防水度': -4.8,
#   '顯色度': 6.875,
#   '飽和度': 4.0},
#  'CHIC CHOC 奇可俏可_電眼星炫筆甜心 CHIC CHOC Magical shiny eyepencil N EX_one_color': {'上色度': 6.8409,
#   '保濕度': -1.5,
#   '持久度': -9.75,
#   '推勻度': 4.125,
#   '種類': '眼線筆',
#   '透亮度': 3.5,
#   '防水度': -3.8571,
#   '顯色度': 3.75,
#   '飽和度': -6.0},
#  'CHICCA_ミスティック ソフトペンシルアイライナー_one_color': {'上色度': 9.8,
#   '保濕度': 0,
#   '持久度': -6.0,
#   '推勻度': 3.5,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.5455,
#   '顯色度': 3.3333,
#   '飽和度': 0},
#  'CLINIQUE 倩碧_極緻纖幼眼線筆 Skinny Sticks_one_color': {'上色度': 9.975,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': -3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 7.4286,
#   '顯色度': 10.0,
#   '飽和度': 0},
#  'CLINIQUE 倩碧_自然細抗暈染眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CLINIQUE 倩碧_魅力眼線筆 Cream Shaper for Eyes_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CLIO 珂莉奧_炫彩防水眼線膠筆 CLIO Gelpresso Waterproof Pencil Gel Liner _one_color': {'上色度': 9.625,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 5.25,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -10.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CLIO 珂莉奧_魅黑防水眼線鉛筆 Clio Kill Black Waterproof Pen liner_one_color': {'上色度': 7.5568,
#   '保濕度': 1.75,
#   '持久度': 8.625,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.4286,
#   '顯色度': 5.0,
#   '飽和度': 6.5},
#  'Calvin Klein_液體眼線筆 LIQUID EYELINE MARKER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Calvin Klein_雙頭眼線筆 DOUBLE-ENDED EYELINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -11.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CathyCat_好萊塢明星筆 Smoky pencil eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Chacott For Professionals_自動眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Chantecaille 香緹卡_24HRs 防水抗暈眼線筆 24 Hour Waterproof Liner_one_color': {'上色度': 6.4915,
#   '保濕度': -0.5147,
#   '持久度': 6.7059,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 1.0455,
#   '防水度': 0.75,
#   '顯色度': 4.3519,
#   '飽和度': 4.8182},
#  'Chantecaille 香緹卡_勻色眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Chantecaille 香緹卡_絲滑光感眼線筆  Luster Glide Silk Infused Eye Liner__NEW_ Black Forest黑霜綠2017秋季': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'CityColor_酷歐蠟筆眼線筆 Auto Eye Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Cosme Decorte 黛珂_舞蝶長效眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Cosme Decorte 黛珂_魅色眼彩筆__NEW_ BR321限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Cosme Decorte 黛珂_魅色眼彩筆__NEW_ PU120限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Creators of Beauty 新萃妍_眼線眼影點粧筆 Crayon Yeux_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Creators of Beauty 新萃妍_雙眼明亮眼線筆_one_color': {'上色度': 8.6333,
#   '保濕度': 0.0,
#   '持久度': 6.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 1.2,
#   '防水度': -1.7436,
#   '顯色度': 4.2857,
#   '飽和度': 0},
#  'DAISO 大創_ellefar可換芯旋轉式眼線筆_one_color': {'上色度': 4.6667,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -0.8,
#   '顯色度': 0,
#   '飽和度': 0},
#  'DAYLA COSMETICS 黛樂美妝_魅眼造型防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'DAZZSHOP_極炫眼線筆 SUPERB EYELINER PENCIL_#02': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'DAZZSHOP_極炫眼線筆 SUPERB EYELINER PENCIL_#04': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'DHC_24H防水防暈眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'DHC_防水防暈眼線膠筆 Gel Pencil Eyeliner EX_one_color': {'上色度': 6.125,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.1538,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'DOTDOT_36H淚眼防水眼線膠筆_one_color': {'上色度': 8.4046,
#   '保濕度': 0.0833,
#   '持久度': 7.6875,
#   '推勻度': 1.875,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 0.0,
#   '顯色度': 5.5769,
#   '飽和度': 6.6},
#  'DOTDOT_防水星紗眼線筆_one_color': {'上色度': 0.0,
#   '保濕度': -0.6667,
#   '持久度': -9.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.4,
#   '顯色度': 4.6875,
#   '飽和度': 0},
#  'De Mon_星燦眉彩眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Dior 迪奧_DIORSHOW搶眼造型眼線膠筆_one_color': {'上色度': 0.7,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Dior 迪奧_彩妝大師眼線筆_one_color': {'上色度': 12.6875,
#   '保濕度': -0.4167,
#   '持久度': 4.25,
#   '推勻度': 5.25,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.6667,
#   '顯色度': 0,
#   '飽和度': 2.0},
#  'Dior 迪奧_搶眼防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Dior 迪奧_輕柔眼線筆 Crayon Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0.25,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -10.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'EGLIPS_持久防水旋轉眼線膠筆_one_color': {'上色度': 7.2188,
#   '保濕度': -0.1667,
#   '持久度': -0.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0.875,
#   '防水度': 2.8387,
#   '顯色度': -1.5625,
#   '飽和度': 4.0},
#  'ELSIA 艾兒希亞_柔芯眼線筆旋轉式 CELFUL ELSIA SOFT EYELINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ETUDE HOUSE_Aloha眼線刺青兩用彩繪筆_one_color': {'上色度': 4.4167,
#   '保濕度': 0.15,
#   '持久度': -0.6,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.25,
#   '防水度': -10.75,
#   '顯色度': 6.0227,
#   '飽和度': 0},
#  'ETUDE HOUSE_十分亮眼晶彩防水眼線筆 PROOF 10 JEWELRY PENCIL_one_color': {'上色度': 8.75,
#   '保濕度': -1.3333,
#   '持久度': 1.875,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 1.1304,
#   '顯色度': 6.0714,
#   '飽和度': 7.0},
#  'ETUDE HOUSE_我很粗心一筆勾翹防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ETUDE HOUSE_最高線速飛快流利眼線筆_one_color': {'上色度': 3.0625,
#   '保濕度': -2.25,
#   '持久度': -6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 4.0},
#  'ETUDE HOUSE_眼技精采神乎其技快乾造型眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ETUDE HOUSE_筆筆皆飾妝模術101炫彩畫筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ETUDE HOUSE_雪藏甜心巧克力棒101炫彩畫筆_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -12.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Elegance_眼線筆 EYE STYLING PENCIL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Elizabeth Arden 伊麗莎白雅頓_誘色情迷眼線筆 Intrigue Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -14.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Estee Lauder 雅詩蘭黛_星燦好萊塢限量眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Estee Lauder 雅詩蘭黛_煙燻限量眼影筆 MAGIC SMOKY POWDER SHADOW STICK_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.6667,
#   '顯色度': 0,
#   '飽和度': 4.0},
#  'Estee Lauder 雅詩蘭黛_粉持久超級防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -12.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Estee Lauder 雅詩蘭黛_純色晶灩銀河光感雙頭眼線筆 Pure Color Intense Kajal Eye Crayon Duo_one_color': {'上色度': 9.625,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Estee Lauder 雅詩蘭黛_自動眼線筆 Automatic Pencil for Eyes_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Estee Lauder 雅詩蘭黛_艷夏女神2011限量雙頭眼彩筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'FORTE 台塑生醫_光燦旋轉式自動眼線筆_one_color': {'上色度': 7.5833,
#   '保濕度': -0.7,
#   '持久度': 4.05,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -6.7778,
#   '顯色度': 3.75,
#   '飽和度': 0},
#  'Fasio 菲希歐_濃色零暈染眼線筆 Fasio Pencil Eye Liner D Water Proof_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Fasio 菲希歐_超持粧眼線液筆_one_color': {'上色度': 7.35,
#   '保濕度': 0.25,
#   '持久度': -9.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.5,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Fasio 菲希歐_速乾眼線膠筆 Quick Dry Gel Liner_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'Fasio 菲希歐_零暈染濃色眼線膠筆 FASIO LASTING GEL LINER_one_color': {'上色度': 0,
#   '保濕度': 1.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': -7.0},
#  'GIORGIO ARMANI 亞曼尼_Maestro Liquid Eye Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'GIORGIO ARMANI 亞曼尼_決戰時尚流光眼線筆_one_color': {'上色度': 4.9,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.2593,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'GIVENCHY 紀梵希_防水訂製眼線筆_one_color': {'上色度': 4.97,
#   '保濕度': -0.8958,
#   '持久度': 4.125,
#   '推勻度': 3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.7959,
#   '顯色度': 5.75,
#   '飽和度': 6.6},
#  'GIVENCHY 紀梵希_魅力眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'GUERLAIN 嬌蘭_俄羅斯眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'GUERLAIN 嬌蘭_摩洛哥女神眼影眼線兩用筆 TERRACOTTA FARD METAL EYE SHADOW _ LINER_one_color': {'上色度': 9.3333,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'GUERLAIN 嬌蘭_神秘光眼彩棒_one_color': {'上色度': 9.625,
#   '保濕度': -1.375,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 3.5,
#   '防水度': 10.0,
#   '顯色度': 0,
#   '飽和度': 1.6667},
#  'GUERLAIN 嬌蘭_超持妝防水眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'HABA_美型魅力眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'HELENA RUBINSTEIN_豔魅絕黑眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'HOLIKA HOLIKA_完美魔繪長效型防暈染眼線筆 wonder drawing 24HR auto eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'HOLIKA HOLIKA_華麗深邃防水兩用眼線膠筆 Jewel-light Waterproof Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 3.0,
#   '防水度': 0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'INTEGRATE_俐落極細眼線筆 第二代_one_color': {'上色度': 0,
#   '保濕度': -1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.6667,
#   '顯色度': 0,
#   '飽和度': 0},
#  'INTEGRATE_超順手抗暈染眼線膠筆__NEW_ BK999俐落黑': {'上色度': 6.8414,
#   '保濕度': -0.1149,
#   '持久度': 3.9403,
#   '推勻度': 1.8125,
#   '種類': '眼線筆',
#   '透亮度': 1.5385,
#   '防水度': -1.8593,
#   '顯色度': 6.1828,
#   '飽和度': 4.1765},
#  'INTEGRATE_超順手抗暈眼線膠筆_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 3.6,
#   '顯色度': 5.0,
#   '飽和度': 4.0},
#  'IPSA 茵芙莎_3D微整型眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'IPSA 茵芙莎_幻顏整型眼唇描筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'IPSA 茵芙莎_眉眼描繪組_one_color': {'上色度': 7.875,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'IPSA 茵芙莎_眼型描繪筆蕊Ｎ_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'IPSA 茵芙莎_隱形眼線筆_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'JILL STUART 吉麗絲朵_恆魅眼線膠筆_one_color': {'上色度': 4.4936,
#   '保濕度': -0.3967,
#   '持久度': 4.6667,
#   '推勻度': 2.1923,
#   '種類': '眼線筆',
#   '透亮度': 1.7727,
#   '防水度': 1.3372,
#   '顯色度': 5.5128,
#   '飽和度': 1.3333},
#  'JILL STUART 吉麗絲朵_絢色眼線筆 Crayon eyeliner_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 6.75,
#   '推勻度': 3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Jane Iredale 愛芮兒‧珍_眉眼線筆 Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 12.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Jealousness 婕洛妮絲_防水眼線膠筆_one_color': {'上色度': 2.3068,
#   '保濕度': 0.2083,
#   '持久度': 3.4286,
#   '推勻度': 3.375,
#   '種類': '眼線筆',
#   '透亮度': 2.75,
#   '防水度': -0.9524,
#   '顯色度': 1.25,
#   '飽和度': 4.0},
#  'Jean Paul Gaultier 高堤耶_高堤耶男性 明眸修飾筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'K-Palette_24H完美持久眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -14.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KALOYA_魅眼誘人防水眼線筆_E02純粹咖啡': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KALOYA_魅眼誘人防水眼線筆_E04香檳玫瑰': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KATE TOKYO 凱婷_一筆流暢眼線筆_one_color': {'上色度': 3.7917,
#   '保濕度': 0,
#   '持久度': -0.375,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 2.1667,
#   '防水度': -0.6667,
#   '顯色度': -0.625,
#   '飽和度': 5.3333},
#  'KATE TOKYO 凱婷_極細持色眼線膠筆_one_color': {'上色度': 7.5066,
#   '保濕度': 0.175,
#   '持久度': 4.95,
#   '推勻度': 4.5,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -0.4,
#   '顯色度': 1.25,
#   '飽和度': 7.0},
#  'KATE TOKYO 凱婷_細緻柔黑眼線筆_one_color': {'上色度': 8.3125,
#   '保濕度': 0,
#   '持久度': 3.5,
#   '推勻度': 4.5,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.8333,
#   '顯色度': 3.3333,
#   '飽和度': 0},
#  'KATE TOKYO 凱婷_超細鎖色眼線膠筆_one_color': {'上色度': 6.3073,
#   '保濕度': -0.3989,
#   '持久度': 2.8977,
#   '推勻度': 0.375,
#   '種類': '眼線筆',
#   '透亮度': 2.875,
#   '防水度': 0.3333,
#   '顯色度': 3.9583,
#   '飽和度': 4.6364},
#  'KATE TOKYO 凱婷_進化版極限魅惑雙用眼線筆_one_color': {'上色度': 5.6467,
#   '保濕度': -0.6184,
#   '持久度': 5.0094,
#   '推勻度': -0.75,
#   '種類': '眼線筆',
#   '透亮度': 0.9375,
#   '防水度': 3.7361,
#   '顯色度': 5.9783,
#   '飽和度': 2.76},
#  'KISS ME 奇士美-開架_BiBo Pretty俏眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 10.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KISS ME 奇士美-開架_Heavy Rotation濃黑旋轉式眼線筆N Heavy Rotation Perfect Eyeliner N_one_color': {'上色度': 9.3333,
#   '保濕度': -1.375,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KISS ME 奇士美-開架_Heavy Rotation防水眼線膠筆 Heavy Rotation gel pencil eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KOJI_Dolly Wink 眼線筆 Dolly Wink Pencil Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KOSE 高絲-專櫃_幻粧 極濃眼線筆 CRAYON  EYE LINER_one_color': {'上色度': 7.6447,
#   '保濕度': 0,
#   '持久度': 7.5,
#   '推勻度': 3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.8095,
#   '顯色度': -7.5,
#   '飽和度': -6.0},
#  'KOSE 高絲-專櫃_自在持久眼線筆__NEW_ BK002限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KOSE 高絲-專櫃_自在持久眼線筆__NEW_ BR301洗鍊卡其咖啡限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'KRYOLAN 歌劇魅影_魅惑煙燻筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Kanebo 佳麗寶-專櫃_晶巧持久眼線筆_one_color': {'上色度': 5.6875,
#   '保濕度': 0,
#   '持久度': 3.6667,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 4.3158,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'Kanebo 佳麗寶-專櫃_晶巧纖柔眼線筆 STYLING GEL EYELINER_one_color': {'上色度': -0.875,
#   '保濕度': -1.0,
#   '持久度': 1.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.3529,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'Kanebo 佳麗寶-專櫃_立體眼采筆 Eye Pencil N_one_color': {'上色度': 12.25,
#   '保濕度': 0.25,
#   '持久度': 10.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 12.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Kanebo 佳麗寶-專櫃_長效立體眼線筆 Pencil Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -14.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Kiss Me 奇士美-專櫃_極細眼線筆 Ferme Lasting eyeliner  _one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LA SPLASH 愛炫彩妝_眉開眼笑眼線筆 eye_pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_流金雙彩眼線筆_one_color': {'上色度': 9.625,
#   '保濕度': 0,
#   '持久度': 7.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 10.0,
#   '顯色度': 11.25,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_立體大眼防水眼線筆 Crayon WP_one_color': {'上色度': -10.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -12.0,
#   '顯色度': -1.25,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_粉漾玫瑰眼彩筆_21 閃耀銀灰': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_粉漾玫瑰眼彩筆_23 粉紫玫瑰': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LANCOME 蘭蔻_絕對深邃眼線筆 KHOL HYPNOSE WP_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'LANEIGE 蘭芝_寶石光防水眼線筆 Creamy Crystal Waterproof Eyeliner_one_color': {'上色度': 8.5312,
#   '保濕度': 0,
#   '持久度': 9.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -0.8889,
#   '顯色度': 4.375,
#   '飽和度': 0},
#  'LB_超極限持久抗暈眼線膠筆_one_color': {'上色度': 7.3646,
#   '保濕度': 1.0,
#   '持久度': 1.2,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.0,
#   '顯色度': 1.3889,
#   '飽和度': 4.0},
#  'LB_鮮奶油超防水眼影眼線膠筆_流星黑': {'上色度': 6.3025,
#   '保濕度': -0.467,
#   '持久度': 2.8875,
#   '推勻度': 1.0625,
#   '種類': '眼線筆',
#   '透亮度': 2.6562,
#   '防水度': 2.5926,
#   '顯色度': 5.1316,
#   '飽和度': 5.5294},
#  'LB_鮮奶油超防水眼影眼線膠筆_華麗深藍': {'上色度': 6.3025,
#   '保濕度': -0.467,
#   '持久度': 2.8875,
#   '推勻度': 1.0625,
#   '種類': '眼線筆',
#   '透亮度': 2.6562,
#   '防水度': 2.5926,
#   '顯色度': 5.1316,
#   '飽和度': 5.5294},
#  'LB_鮮奶油超防水眼影眼線膠筆_魅惑卡奇': {'上色度': 6.3025,
#   '保濕度': -0.467,
#   '持久度': 2.8875,
#   '推勻度': 1.0625,
#   '種類': '眼線筆',
#   '透亮度': 2.6562,
#   '防水度': 2.5926,
#   '顯色度': 5.1316,
#   '飽和度': 5.5294},
#  'LISSAGE_コントラストアイライナーa_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'L`OREAL PARiS 巴黎萊雅_炫彩柔滑眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Lavshuca_美型持久眼線筆_one_color': {'上色度': 7.875,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.4286,
#   '顯色度': 8.75,
#   '飽和度': -5.0},
#  'LoveVivi _ Vstyle_引人入勝眼彩筆_one_color': {'上色度': 2.0417,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 11.0,
#   '顯色度': 0.625,
#   '飽和度': 5.0},
#  'MAC_不暈染眼線膠筆 PEARLGLIDE INTENSE EYE LINER_one_color': {'上色度': 3.0625,
#   '保濕度': -1.0,
#   '持久度': 0,
#   '推勻度': -4.5,
#   '種類': '眼線筆',
#   '透亮度': -3.0,
#   '防水度': 0.5,
#   '顯色度': 8.75,
#   '飽和度': 5.5},
#  'MAC_寶萊塢防水眼線筆_one_color': {'上色度': 9.5375,
#   '保濕度': -1.375,
#   '持久度': -3.45,
#   '推勻度': 3.15,
#   '種類': '眼線筆',
#   '透亮度': 0.8333,
#   '防水度': -2.0526,
#   '顯色度': -2.0833,
#   '飽和度': -6.0},
#  'MAC_持妝防水眼線筆 POWERPOINT EYE PENCIL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MAC_時尚眼彩筆 EYE KOHL_one_color': {'上色度': 8.037,
#   '保濕度': -0.9,
#   '持久度': 4.425,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.0137,
#   '顯色度': 2.6389,
#   '飽和度': 6.4},
#  'MAC_眼線造型筆 EYE PENCIL_one_color': {'上色度': 6.4167,
#   '保濕度': 0,
#   '持久度': -1.9286,
#   '推勻度': 4.125,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.381,
#   '顯色度': 7.75,
#   '飽和度': 0},
#  'MAC_粉持色眼線筆_one_color': {'上色度': 9.6532,
#   '保濕度': 0,
#   '持久度': 7.5,
#   '推勻度': 0.9375,
#   '種類': '眼線筆',
#   '透亮度': 2.5,
#   '防水度': -4.8667,
#   '顯色度': 5.2778,
#   '飽和度': 6.6667},
#  'MAC_迪斯可雙色亮片眼彩筆 Dual Edge EYE Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MAJOLICA MAJORCA 戀愛魔鏡_亮眼珠光眼線筆_one_color': {'上色度': 9.25,
#   '保濕度': -1.0,
#   '持久度': 2.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.4,
#   '顯色度': 11.25,
#   '飽和度': 7.0},
#  'MAJOLICA MAJORCA 戀愛魔鏡_愛線狂防暈眼線筆__NEW_ BK999曜石黑': {'上色度': 10.25,
#   '保濕度': -1.0,
#   '持久度': -1.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 1.9615,
#   '防水度': 12.0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'MAJOLICA MAJORCA 戀愛魔鏡_愛線狂防暈眼線筆__NEW_ PK777玫瑰金': {'上色度': 6.8478,
#   '保濕度': -1.35,
#   '持久度': 8.1,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 3.8,
#   '顯色度': 5.0,
#   '飽和度': 6.5},
#  'MAKE UP FOR EVER_AQUA防水眼線筆_one_color': {'上色度': 6.2136,
#   '保濕度': 0.381,
#   '持久度': 1.7206,
#   '推勻度': 5.0625,
#   '種類': '眼線筆',
#   '透亮度': 3.5,
#   '防水度': -1.0502,
#   '顯色度': 7.0221,
#   '飽和度': 5.2667},
#  'MAKE UP FOR EVER_瘋搖滾派對五色眼線筆盒_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'MAKE UP FOR EVER_絢墨眼彩筆 Kohl Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MARY KAY 玫琳凱_童話精靈眼線筆_one_color': {'上色度': -9.625,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 14.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_亮彩流暢眼線筆 IMPACT EXPRESS Smooth Felt Liner_one_color': {'上色度': 8.05,
#   '保濕度': 0,
#   '持久度': 10.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_恆久尖銳柔滑眼線膠筆 Ever Sharp Liner_one_color': {'上色度': 6.5625,
#   '保濕度': -0.1875,
#   '持久度': -1.8,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 2.3636,
#   '防水度': -2.75,
#   '顯色度': 2.5,
#   '飽和度': 0},
#  'MAYBELLINE 媚比琳_色計師持久愛線防水眼線膠筆_one_color': {'上色度': 5.8956,
#   '保濕度': -0.8265,
#   '持久度': 3.2812,
#   '推勻度': 2.5312,
#   '種類': '眼線筆',
#   '透亮度': 2.75,
#   '防水度': 0.249,
#   '顯色度': 6.6964,
#   '飽和度': 4.6207},
#  'MISSHA_眼線筆 Eyeliner Pencil_one_color': {'上色度': 10.5,
#   '保濕度': 0,
#   '持久度': -6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 3.5,
#   '防水度': -3.5,
#   '顯色度': 8.125,
#   '飽和度': -0.5},
#  'MKUP 美咖_超激細深黑眼線筆極細_one_color': {'上色度': 1.5,
#   '保濕度': -1.75,
#   '持久度': -3.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.0,
#   '顯色度': 6.875,
#   '飽和度': 0},
#  'MODAmassa 瑪丹‧摩莎_眼線筆 Eyeliner Pencil_one_color': {'上色度': 10.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -10.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'MSH_Love Pencil隨心所慾防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Mamonde_Gel In Waterproof Shadow Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.5,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maryquant 瑪莉官_MQ眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maxfactor 蜜絲佛陀_眼線筆 Eyeliner Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Maxfactor 蜜絲佛陀_雙效持久眼線筆_one_color': {'上色度': 2.3333,
#   '保濕度': 0,
#   '持久度': 2.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -9.0,
#   '顯色度': 0,
#   '飽和度': 5.5},
#  'Miki Queen_超防水抗暈眼線膠筆_one_color': {'上色度': 4.0833,
#   '保濕度': 0,
#   '持久度': -6.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -5.1111,
#   '顯色度': 4.1667,
#   '飽和度': 0},
#  'Milani_LIQUIF EYE Metallic Eyeliner Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Miss Hana 花娜小姐_不掉色眉瞳唇頰四效筆_one_color': {'上色度': 9.9167,
#   '保濕度': -0.1667,
#   '持久度': 0.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 9.2727,
#   '顯色度': 0,
#   '飽和度': 5.5},
#  'Miss Hana 花娜小姐_快乾防暈絲絨煙燻旋轉眼膠筆_one_color': {'上色度': 6.7965,
#   '保濕度': -0.2538,
#   '持久度': 1.9828,
#   '推勻度': 3.6094,
#   '種類': '眼線筆',
#   '透亮度': 2.75,
#   '防水度': -0.0474,
#   '顯色度': 4.6269,
#   '飽和度': 3.7561},
#  'MuGu_閃亮大眼炫彩筆_one_color': {'上色度': 9.1,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 3.9375,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 12.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'NAF_36H超防水持久眼線膠筆升級版_one_color': {'上色度': 7.3889,
#   '保濕度': 0,
#   '持久度': -1.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -5.0909,
#   '顯色度': 0,
#   '飽和度': -6.0},
#  'NARS_女王眼線膠筆 NIGHT SERIES EYELINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'NARS_敢愛誘黑眼線筆 KOHLINER_one_color': {'上色度': 8.75,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'NARS_絕世大眼女王眼線膠筆 Larger Than Life Long Wear Eyeliner_one_color': {'上色度': -10.5,
#   '保濕度': 0,
#   '持久度': 10.5,
#   '推勻度': 5.25,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -4.5,
#   '顯色度': 7.5,
#   '飽和度': 4.0},
#  'NYX_流暢持久眼線筆_one_color': {'上色度': -9.625,
#   '保濕度': 0,
#   '持久度': -8.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -12.0,
#   '顯色度': -6.25,
#   '飽和度': 0},
#  'NYX_閃爍珍珠眼唇兩用筆 Glitter Mania Jumbo Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 5.75,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -8.0,
#   '顯色度': 5.0,
#   '飽和度': -6.0},
#  'Naris Up 娜麗絲_完美model煙燻眼線筆_one_color': {'上色度': 7.0,
#   '保濕度': -0.6667,
#   '持久度': 4.8,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 3.0,
#   '防水度': 4.0,
#   '顯色度': 7.8125,
#   '飽和度': 0},
#  'Nature Republic_漂亮樹自動眼線筆 Pretty Tree Auto Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 1.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -10.0,
#   '顯色度': 5.0,
#   '飽和度': 4.0},
#  'Nu Skin 如新_賦采緞柔眼線筆 Nu Colour Defining Effects Smooth Eyeliner_one_color': {'上色度': 13.125,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'O HUI 歐蕙_紫晶恆彩自動眼線筆 AUTO PENCIL EYELINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': -7.5,
#   '推勻度': -3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'OGUMA 水美媒_晶燦黑放大眼線膠筆 Flash Black Eye Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'PALGANTONG 劇場魔匠_魅眼紋身Combi雙頭眼線筆 Eyeliner Combi Pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'PUPA_城市探險魅力深邃眼線筆 KILLER KAJAL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'PUPA_東方風情嬉戲眼線筆 Triple Use Eyeliner Pencil Kajal_ Eyeliner_ Eye_one_color': {'上色度': 15.75,
#   '保濕度': -1.0833,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -10.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Prestige_Total Intensity Eyeliner_one_color': {'上色度': 12.25,
#   '保濕度': -1.75,
#   '持久度': 12.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.6364,
#   '顯色度': 7.9167,
#   '飽和度': 9.0},
#  'REVLON 露華濃_持久柔滑眼線筆_one_color': {'上色度': -0.5833,
#   '保濕度': -0.15,
#   '持久度': 4.125,
#   '推勻度': -5.25,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0645,
#   '顯色度': 5.8333,
#   '飽和度': 3.4},
#  'REVLON 露華濃_超持色絕不失手濃密眼線膠筆 COLORSTAY Eyeliner_one_color': {'上色度': 8.4583,
#   '保濕度': -1.75,
#   '持久度': 3.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.0588,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'RMK_時尚雙巧眼彩棒眼線 RMK W On Eyes Eye Liner_one_color': {'上色度': 8.2708,
#   '保濕度': -0.15,
#   '持久度': 3.2857,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -0.6667,
#   '顯色度': 6.875,
#   '飽和度': 6.5},
#  'RMK_精巧眼線筆N RMK Ingenious Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'RMK_雙頭眼線筆_one_color': {'上色度': 2.0417,
#   '保濕度': 1.0,
#   '持久度': 1.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.125,
#   '顯色度': 0,
#   '飽和度': 4.0},
#  'Red Earth 紅地球_眼類雙用筆 Eye Shadow Multi-Pencil_one_color': {'上色度': 8.4318,
#   '保濕度': 1.25,
#   '持久度': 8.0,
#   '推勻度': 4.5,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -8.3529,
#   '顯色度': 8.3333,
#   '飽和度': 0},
#  'SANA 莎娜_速捷魅力眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'SHISEIDO 資生堂-專櫃_恬蜜花漾眼線筆_one_color': {'上色度': 4.9412,
#   '保濕度': -0.375,
#   '持久度': 3.9,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -1.1429,
#   '顯色度': 7.5,
#   '飽和度': -6.5},
#  'SHISEIDO 資生堂-專櫃_活顏悅色 光采眼線筆 The Makeup Eyeliner Pencil_one_color': {'上色度': 2.625,
#   '保濕度': 0,
#   '持久度': -6.0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.25,
#   '顯色度': 4.8214,
#   '飽和度': 7.0},
#  'SHISEIDO 資生堂-專櫃_長效超激順眼線筆 Long Stay Eyeliner N_one_color': {'上色度': -10.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'SISLEY 希思黎_植物晶鑽眼線筆_one_color': {'上色度': 8.75,
#   '保濕度': 1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.5,
#   '防水度': -8.0,
#   '顯色度': 7.5,
#   '飽和度': 0},
#  'SISLEY 希思黎_漾澤精華眼彩筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'SKINFOOD_布朗尼礦物防暈染眼線膠筆_one_color': {'上色度': -1.75,
#   '保濕度': -1.0,
#   '持久度': 2.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.1,
#   '顯色度': 5.75,
#   '飽和度': -6.0},
#  'SKINFOOD_紫醉魔幻防水眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'SOFINA 蘇菲娜_星鑽美形眼線筆_one_color': {'上色度': 1.9444,
#   '保濕度': -0.75,
#   '持久度': 0.75,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.75,
#   '防水度': 5.3,
#   '顯色度': -8.75,
#   '飽和度': 4.0},
#  'STARSUKI 星希琦_玩眼色絲滑旋轉眼線膠筆_one_color': {'上色度': 15.75,
#   '保濕度': -1.75,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -8.0,
#   '顯色度': 5.0,
#   '飽和度': 4.0},
#  'SUKI_ 睛艷防水眼彩筆_one_color': {'上色度': 7.9891,
#   '保濕度': -0.05,
#   '持久度': 5.25,
#   '推勻度': 3.15,
#   '種類': '眼線筆',
#   '透亮度': 2.3333,
#   '防水度': -6.1622,
#   '顯色度': 5.7143,
#   '飽和度': 4.0},
#  'SUKI_惑星之眼眼線筆4D書寫型_one_color': {'上色度': 11.375,
#   '保濕度': -1.75,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 10.0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'SUQQU_晶采絕色眼線膠筆_one_color': {'上色度': 1.75,
#   '保濕度': 0,
#   '持久度': -6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'SWEETS SWEETS_長效防暈眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Sasatinnie_超持久防水眼線筆 Waterproof Smooth Gel Eyeliner Pen_one_color': {'上色度': 7.0,
#   '保濕度': -1.0,
#   '持久度': 8.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.5714,
#   '顯色度': 6.875,
#   '飽和度': 0},
#  'Solone_30秒定妝慕絲眼線眼彩筆_one_color': {'上色度': 5.25,
#   '保濕度': -0.0833,
#   '持久度': 1.1,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 2.4571,
#   '顯色度': 2.6562,
#   '飽和度': 0.6667},
#  'Solone_奇幻繽紛慕絲眼彩筆 Vivid Fantasy Smoody Pencil_01': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Solone_奇幻繽紛慕絲眼彩筆 Vivid Fantasy Smoody Pencil_03': {'上色度': 7.1518,
#   '保濕度': -0.195,
#   '持久度': 4.6458,
#   '推勻度': 2.4759,
#   '種類': '眼線筆',
#   '透亮度': 1.8553,
#   '防水度': 1.0098,
#   '顯色度': 4.6528,
#   '飽和度': 5.5882},
#  'Solone_奇幻繽紛慕絲眼彩筆 Vivid Fantasy Smoody Pencil_05': {'上色度': 7.1518,
#   '保濕度': -0.195,
#   '持久度': 4.6458,
#   '推勻度': 2.4759,
#   '種類': '眼線筆',
#   '透亮度': 1.8553,
#   '防水度': 1.0098,
#   '顯色度': 4.6528,
#   '飽和度': 5.5882},
#  'Solone_奇幻繽紛慕絲眼彩筆 Vivid Fantasy Smoody Pencil_07': {'上色度': 7.1518,
#   '保濕度': -0.195,
#   '持久度': 4.6458,
#   '推勻度': 2.4759,
#   '種類': '眼線筆',
#   '透亮度': 1.8553,
#   '防水度': 1.0098,
#   '顯色度': 4.6528,
#   '飽和度': 5.5882},
#  'Solone_完美勾勒眼線膠筆 Perfect Drawing Eyeliner _one_color': {'上色度': 7.1518,
#   '保濕度': -0.195,
#   '持久度': 4.6458,
#   '推勻度': 2.4759,
#   '種類': '眼線筆',
#   '透亮度': 1.8553,
#   '防水度': 1.0098,
#   '顯色度': 4.6528,
#   '飽和度': 5.5882},
#  'Solone_玫瑰公主花園防水眼線膠筆_one_color': {'上色度': 4.5294,
#   '保濕度': -0.4231,
#   '持久度': 3.25,
#   '推勻度': 1.5,
#   '種類': '眼線筆',
#   '透亮度': 4.0,
#   '防水度': -0.9371,
#   '顯色度': 4.6591,
#   '飽和度': 2.2},
#  'Solone_防水眼線膠筆_one_color': {'上色度': -12.25,
#   '保濕度': -0.0833,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -18.0,
#   '顯色度': -8.75,
#   '飽和度': 0},
#  'Sonia Rykiel_漩色迷情限量眼線筆 TWISTED EYELINER PENCIL_one_color': {'上色度': 0,
#   '保濕度': 1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': -7.5,
#   '飽和度': 0},
#  'THE FACE SHOP 菲詩小舖_MARVEL系列印墨抗暈眼線膠筆__NEW_  03紅限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'THE FACE SHOP 菲詩小舖_MARVEL系列印墨抗暈眼線膠筆__NEW_ 02棕限量': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'THE FACE SHOP 菲詩小舖_混血甜心-星燦電眼防水眼線筆 LOVELY MEEX MAKE ME STAR WATERPROOF GEL LINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'THE FACE SHOP 菲詩小舖_眼線筆鉛筆_one_color': {'上色度': 7.5662,
#   '保濕度': 0.875,
#   '持久度': 2.7353,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -6.7349,
#   '顯色度': 5.7692,
#   '飽和度': 4.0},
#  'THE FACE SHOP 菲詩小舖_魔髮精靈－2mm極細眼線筆_one_color': {'上色度': -8.75,
#   '保濕度': 1.0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'THREE_魅光星采筆_one_color': {'上色度': 0.0,
#   '保濕度': 1.5,
#   '持久度': 7.5,
#   '推勻度': -4.5,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': 7.2,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'THREE_魅光眼采筆 _one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -6.4,
#   '顯色度': 0,
#   '飽和度': 0},
#  'TOM FORD_EYE DEFINING PENCIL_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'The Body Shop 美體小舖_啞緻柔滑眼線筆 Matte Kajal Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'The Body Shop 美體小舖_潤澤眼線筆 Eye Definer_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'The Body Shop 美體小舖_碳黑防暈染防水眼線筆_one_color': {'上色度': -5.25,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.3333,
#   '顯色度': 0,
#   '飽和度': 0},
#  'The Body Shop 美體小舖_花漾霓彩雙色眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'The Body Shop 美體小舖_魅彩極光持久眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Theophile 泰奧菲_絲緞眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Tony _ Tina_色彩能量閃爍眼線筆_one_color': {'上色度': 11.375,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -12.4,
#   '顯色度': 0,
#   '飽和度': 0},
#  'URBAN DECAY_247眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'VINA 友娜_晶炫超防水眼線筆眉筆兩用 Super long wear _ waterproof glitter eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'VISEE_柔滑魅色眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'VISEE_絲滑抗暈眼彩筆__NEW_ RD8勃根地紅限量': {'上色度': 2.45,
#   '保濕度': 1.5,
#   '持久度': 7.0,
#   '推勻度': -0.75,
#   '種類': '眼線筆',
#   '透亮度': 3.5,
#   '防水度': -1.0588,
#   '顯色度': 6.25,
#   '飽和度': 0},
#  'VISEE_雙效立體眼線筆 SHADOW _ LIQUID EYELINER_one_color': {'上色度': 2.2885,
#   '保濕度': -1.5,
#   '持久度': 3.9,
#   '推勻度': -1.5,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -1.1304,
#   '顯色度': 5.25,
#   '飽和度': 0},
#  'VOV_極緻漾眼娃娃眼線筆_one_color': {'上色度': -10.5,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': -0.5,
#   '防水度': 0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'VOV_花神自動眼線筆_one_color': {'上色度': 4.0833,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -3.0,
#   '顯色度': 0.625,
#   '飽和度': 0},
#  'VOV_魔力電眼眼線筆_one_color': {'上色度': 5.9792,
#   '保濕度': 0.25,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -1.2308,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'WOWWOW_3X黑魅魔幻眼線筆 3X Magictip Liquid Eyeliner Pen_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'WinkO Cosmetics 葳珂彩妝_愛來了持色眼線膠筆_one_color': {'上色度': 13.4167,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 13.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'YSL 聖羅蘭_3合1時尚聚焦眼彩筆限量_one_color': {'上色度': 0.0,
#   '保濕度': -1.75,
#   '持久度': -9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'YSL 聖羅蘭_艷彩眼線筆_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 8.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'Yves Rocher 伊夫‧黎雪_絕色三合一眼彩筆_one_color': {'上色度': 0,
#   '保濕度': -1.0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 4.0,
#   '顯色度': 0,
#   '飽和度': 4.0},
#  'Za_旋轉眼線筆_one_color': {'上色度': 4.6786,
#   '保濕度': 0.15,
#   '持久度': 5.4375,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -0.9429,
#   '顯色度': -0.1389,
#   '飽和度': 4.0},
#  'agnes b_10小時防水零暈染輕柔眼線筆 CONTOUR HAUTE DEF_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'agnes b_純淨自然眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'banila co_Seoul 順滑眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'butyshop_防水定妝眼膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'cle de peau Beaute 肌膚之鑰_眼線描繪筆 crayon pour les yeux_one_color': {'上色度': 7.2917,
#   '保濕度': -2.25,
#   '持久度': 7.5,
#   '推勻度': -4.5,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -6.25,
#   '顯色度': -0.3125,
#   '飽和度': 0},
#  'cosmos_超防水眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'dejavu_就是不暈持久眼膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'elite_矚目眼線筆 WOODEN EYEPENCIL_one_color': {'上色度': 5.25,
#   '保濕度': 0.425,
#   '持久度': 0.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 4.0,
#   '防水度': -1.4667,
#   '顯色度': 3.75,
#   '飽和度': 0.5},
#  'elite_黑夜晶燦眼線筆 INTENSITY EYE PENCIL_one_color': {'上色度': 5.4022,
#   '保濕度': -0.35,
#   '持久度': 3.5625,
#   '推勻度': 4.5,
#   '種類': '眼線筆',
#   '透亮度': 4.0,
#   '防水度': -1.1111,
#   '顯色度': 9.1667,
#   '飽和度': 6.0},
#  'essence_二合一眼影眼線筆_one_color': {'上色度': -0.4375,
#   '保濕度': -1.25,
#   '持久度': 7.5,
#   '推勻度': -3.75,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 4.0,
#   '顯色度': 1.25,
#   '飽和度': 0},
#  'ettusais 艾杜紗_幻色眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ettusais 艾杜紗_眼線繪畫筆 EYELINER pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'ettusais 艾杜紗_瞬黑眼線膠筆 Creamy Eyeliner WP_one_color': {'上色度': 6.65,
#   '保濕度': 1.5,
#   '持久度': 0.75,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -0.3571,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'excel_3合1炫目眼線液 PERFECT EYELINER N__NEW_ 01黑色': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'excel_3合1炫目眼線液 PERFECT EYELINER N__NEW_ 03深棕色': {'上色度': -11.375,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -16.0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'excel_持久眼線液 LIQUID EYELINER EX__NEW_ 02棕色': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'fox_防水眼線膠筆 All Day Gel Eyeliner_one_color': {'上色度': 6.4167,
#   '保濕度': -1.0,
#   '持久度': -2.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 10.0,
#   '顯色度': 7.5,
#   '飽和度': 0},
#  'heme_愛放電防水眼線膠筆 Heme x Hello Kitty Shimmer Waterproof Eyeliner _one_color': {'上色度': 10.5,
#   '保濕度': 0,
#   '持久度': 9.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 10.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'heme_玩色派對防水眼線慕斯筆_one_color': {'上色度': -0.4375,
#   '保濕度': 0.0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 3.6,
#   '顯色度': -7.5,
#   '飽和度': 0},
#  'innisfree_一筆勾削眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'innisfree_妝自然淚光閃閃雙頭眼線筆 Eco Dual Tear Drop Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'innisfree_妝自然防水眼線筆 Eco WP Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'laura mercier 蘿拉蜜思_eye pencil_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'laura mercier 蘿拉蜜思_時尚霓采眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'laura mercier 蘿拉蜜思_霓采煙薰眼線筆 Eye Pencil - Kohl_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 8.75,
#   '飽和度': 0},
#  'media 媚點_柔滑濃黑眼線筆_one_color': {'上色度': 4.6667,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 3.0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -11.5,
#   '顯色度': 0,
#   '飽和度': 0},
#  'mfc_防水型兩用眉眼線筆_one_color': {'上色度': 5.1683,
#   '保濕度': 0.2619,
#   '持久度': 1.4605,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.6421,
#   '顯色度': 3.2212,
#   '飽和度': -2.0},
#  'motives 莫蒂膚_眼線筆 Khol Eyeliner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'peripera_冰沙亮眼防水眼線筆 Waterproof Pencil Liner_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'shu uemura 植村秀_3秒魔法全能眼線膠筆 GEL PENCIL EYELINER_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'shu uemura 植村秀_新一代 3秒魔法眼線膠筆_one_color': {'上色度': -10.5,
#   '保濕度': -0.125,
#   '持久度': 0,
#   '推勻度': -4.5,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -2.6667,
#   '顯色度': 0,
#   '飽和度': 0},
#  'shu uemura 植村秀_炫彩絲滑眼彩筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'shu uemura 植村秀_玩色塗鴉眼線筆 eye color pencil_one_color': {'上色度': 6.0329,
#   '保濕度': -0.1364,
#   '持久度': 1.35,
#   '推勻度': 1.7812,
#   '種類': '眼線筆',
#   '透亮度': 1.75,
#   '防水度': -3.6923,
#   '顯色度': 4.25,
#   '飽和度': 4.8571},
#  'shu uemura 植村秀_美麗無畏眼線膠筆 14SA GEL PENCIL LINER GREEN OS_one_color': {'上色度': 7.0,
#   '保濕度': -1.0,
#   '持久度': 0,
#   '推勻度': 5.25,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 8.0,
#   '顯色度': -8.75,
#   '飽和度': -1.5},
#  'shu uemura 植村秀_防水眼線膠筆 GEL PENCIL EYELINER_one_color': {'上色度': 2.625,
#   '保濕度': 1.5,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.1667,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'shu uemura 植村秀_限量版夏の花火眼線筆 SHIMMER EYE LINER_one_color': {'上色度': 9.9167,
#   '保濕度': -1.0,
#   '持久度': 8.25,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'smashbox_8小時防水眼彩筆 LIMITLESS WATERPROOF EYE LINER_one_color': {'上色度': 8.0041,
#   '保濕度': 0.0625,
#   '持久度': 2.85,
#   '推勻度': 0.375,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -4.3052,
#   '顯色度': 2.2581,
#   '飽和度': -0.25},
#  'smashbox_Wish煙燻眼彩筆_one_color': {'上色度': -8.75,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0.0,
#   '顯色度': 5.0,
#   '飽和度': 0},
#  'smashbox_掃黑防水眼線筆_one_color': {'上色度': 2.1,
#   '保濕度': 1.25,
#   '持久度': 6.0,
#   '推勻度': -4.5,
#   '種類': '眼線筆',
#   '透亮度': 2.0,
#   '防水度': -4.5,
#   '顯色度': -1.25,
#   '飽和度': 4.0},
#  'smashbox_防水眼彩筆_one_color': {'上色度': 0,
#   '保濕度': 1.75,
#   '持久度': 13.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': -13.5,
#   '顯色度': 0,
#   '飽和度': 0},
#  'stila_勾影恆色眼墨筆 kajal eye liner_one_color': {'上色度': 7.0,
#   '保濕度': 0,
#   '持久度': 10.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'terre d`Oc_多變線條美-眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  'too cool for school_恐龍眼線膠筆 DinoPlatz Highline_one_color': {'上色度': 3.15,
#   '保濕度': 1.5,
#   '持久度': 13.5,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 1.0,
#   '顯色度': 8.75,
#   '飽和度': 7.0},
#  'too cool for school_素描眼線筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0},
#  '~H2O+ 水貝爾_定型眼線筆 Definitive Eye Liner_one_color': {'上色度': 12.25,
#   '保濕度': 0,
#   '持久度': 6.0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 12.0,
#   '顯色度': 5.0,
#   '飽和度': 4.0},
#  '凡爾賽玫瑰_凡爾賽玫瑰瑪莉皇后華麗眼線膠筆_one_color': {'上色度': 0,
#   '保濕度': 0,
#   '持久度': 0,
#   '推勻度': 0,
#   '種類': '眼線筆',
#   '透亮度': 0,
#   '防水度': 0,
#   '顯色度': 0,
#   '飽和度': 0}}

# %%
k
# Out:
# 635

# %%
#眉筆:上色,自然,持久,暈開,顯色,推勻,保濕
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/眉筆/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==(len(files)-1):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    while True:
        try:
            if test['comments']==[]:
                k+=1
                break
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)

            else:
                continue



        j+=1
    try:
        dic['上色度']=round((EasytoCo1)*7/len(EasytoCo),4)
    except ZeroDivisionError:
        dic['上色度']=0
    try:
        dic['自然度']=round((nature1)*6/len(nature),4)
    except ZeroDivisionError:
        dic['自然度']=0
 
            
    try:
        dic['持久度']=round((mainLong1-mainShort1)*5/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['持久度']=0

    try:
        dic['防水度']=round((Waterpro1-UnWaterpro1)*4/len(Waterpro+UnWaterpro),4)
    except ZeroDivisionError:
        dic['防水度']=0


    try:
        dic['顯色度']=round((ShowColor1)*3/len(ShowColor),4)
    except ZeroDivisionError:
        dic['顯色度']=0
        
    try:
        dic['推勻度']=round((blendout1-Unblendout1)*2/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['推勻度']=0

    try:
        dic['保濕度']=round((Water1-Dry1)*1/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['保濕度']=0

    dic['種類']='眉筆'
    dic[product_ID]=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/Score/EyebrowPen_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product

# %%
#粉底液:遮,保濕,持久,透亮,推勻,自然,清爽,浮粉
import json
import jieba.analyse
jieba.load_userdict('/Users/oz/Desktop/test/total_dic.txt')
import glob
files=glob.glob('/Users/oz/Documents/makeup/total/粉底液/*.json')

comma_=['!','...','?','。',',','！','、',' ',':','XD','而且','又','所以','覺得','我','但','也','不過','因為','卻','如果']
long_=['持妝力', '持久性', '持久力', '持久度', '持妝度', '持妝']
short_=['脫妝', '掉色', '調色']
cover_=['遮暇力', '遮瑕力', '遮瑕度', '無暇', '無瑕', '遮暇', '遮住', '遮蓋', '遮瑕']
nature_=['自然感', '自然化']
none_=['保濕成分','保濕精萃','自然光']
Water_=['保濕效果', '保濕能力', '滋潤效果', '保濕滋潤', '保濕力', '保濕度', '滋潤度', '保溼', '特潤', '水水', '滋潤']
Dry_=['偏乾', '脫皮', '乾燥', '太乾', '乾肌', '乾掉', '乾性']
blendout_=['好推勻', '延展性', '推開', '好推', '均勻']
fresh_=['乾爽', '不黏膩']
stick_=['服貼度']
Waterpro_=['防水測試', '防水性', '防水力', '防水度', '防暈染', '抗暈染', '抗汗', '防暈', '抗暈']
UnWaterpro_=['暈染', '暈']
Bright_=['明亮', '打亮', '光澤感', '光澤度', '透亮感', '薄透', '晶透', '清透', '薄薄', '輕薄', '輕透', '光澤']
ColorSaturation_=['飽和度']
ShowColor_=['顯色效果', '顯色度', '顯色力']
EasytoCo_=['軟硬度', '筆芯', '筆蕊', '筆心', '筆頭', '好畫']
soft_=['滑順', '柔軟', '好化', '好畫', '柔', '細']

small_=['一些些', '一點點', '小小', '有點', '稍微', '增加', '略', '偏', '微']
compare_=['剛剛好', '比較好', 'OK', '更加', '比較']
very_=['還蠻', '還滿', '相當', '真的', '十分', '不錯', '不差', '特別', '喜歡', '很棒', '好用', '優秀', '容易', '輕易', '明顯', '滿意', '常常', '粉', '挺', '蠻', '滿', '最', '夠', '特', '好', '易', '強', '優', '佳', '棒', '讚', '高','軟']
super_=['極', '超好', '厲害']
perfect_=['超級無敵他媽的', '超級無敵', '絕對', '超級', '完全', '完美']

Nsmall_=['沒那麼好', '不是太好', '不大會', '不太會', '不會太', '不太好', '不容易', '不怎麼', '不易', '不太', '稍不', '不算']
No_=['不是', '不要', '不能', '沒有', '不會', '不好', '不足', '不夠', '不顯', '沒', '難']
Nsuper_=['太過', '嚴重', '太', '完全不']

k=0
product={}
while True:
    if k ==len(files):
        break
    
    
    mainLong=[]
    mainShort=[]
    cover=[]
    nature=[]
    Water=[]
    Dry=[]
    blendout=[]
    Unblendout=[]
    fresh=[]
    unfresh=[]
    stick=[]
    Unstick=[]
    Waterpro=[]
    UnWaterpro=[]
    Bright=[]
    ColorSaturation=[]
    ShowColor=[]
    EasytoCo=[]


    mainLong1=0
    mainShort1=0
    cover1=0
    nature1=0
    Water1=0
    Dry1=0
    blendout1=0
    Unblendout1=0
    fresh1=0
    unfresh1=0
    stick1=0
    Unstick1=0
    Waterpro1=0
    UnWaterpro1=0
    Bright1=0
    ColorSaturation1=0
    ShowColor1=0
    EasytoCo1=0


    deny=[]
    deny1=[]
    deny2=[]
    deny3=[]
    good=[]
    good1=[]
    good2=[]
    good3=[]
    good4=[]
    normal=[]
    dic={}

    j=0

    with open(files[k]) as f:
        test=json.load(f)
    while True:
        try:
            if test['comments']==[]:
                k+=1
                break
            test1=test['comments'][j]['content']

        except IndexError:
            k+=1
            break
        test1=replaceF(test1,comma_,'，')
        test1=replaceF(test1,long_,'持久')
        test1=replaceF(test1,short_,'脫妝')
        test1=replaceF(test1,cover_,'遮')
        test1=replaceF(test1,nature_,'自然')
        test1=replaceF(test1,none_,'')
        test1=replaceF(test1,Water_,'保濕')
        test1=replaceF(test1,Dry_,'乾')
        test1=replaceF(test1,blendout_,'推勻')
        test1=replaceF(test1,fresh_,'清爽')
        test1=replaceF(test1,stick_,'服貼')
        test1=replaceF(test1,Waterpro_,'防水')
        test1=replaceF(test1,UnWaterpro_,'暈開')
        test1=replaceF(test1,Bright_,'透亮')
        test1=replaceF(test1,ColorSaturation_,'飽和')
        test1=replaceF(test1,ShowColor_,'顯色')
        test1=replaceF(test1,EasytoCo_,'上色')
        test1=replaceF(test1,soft_,'軟')


        test1=replaceF(test1,small_,'小')
        test1=replaceF(test1,compare_,'更')
        test1=replaceF(test1,super_,'超')
        test1=replaceF(test1,perfect_,'非常')

        test1=replaceF(test1,Nsmall_,'不易')
        test1=replaceF(test1,No_,'沒有')
        test1=replaceF(test1,Nsuper_,'無法')




        sentences=test1.split('，')

        for i in sentences:
            if '持久' in i :
                mainLong.append(i)   
                mainLong1+=ScoreF(i)


            if  '脫妝' in i :
                mainShort.append(i)
                mainShort1+=ScoreF(i)

            if '遮' in i :
                cover.append(i) 
                cover1+=ScoreF(i)
            if  '自然' in i :
                nature.append(i)
                nature1+=ScoreF(i)
            if '保濕' in i :
                Water.append(i)
                Water1+=ScoreF(i)

            if  '乾' in i :
                Dry.append(i)
                Dry1+=ScoreF(i)
            if '推勻' in i :
                blendout.append(i)
                blendout1+=ScoreF(i)
            if '卡粉' in i :
                Unblendout.append(i)
                Unblendout1+=ScoreF(i)

            if  '清爽' in i :
                fresh.append(i)
                fresh1+=ScoreF(i)
            if '黏膩' in i :
                unfresh.append(i)
                unfresh1+=ScoreF(i)

            if '服貼' in i :
                stick.append(i)
                stick1+=ScoreF(i)
            if '浮粉' in i :
                Unstick.append(i)
                Unstick1+=ScoreF(i)


            if '防水' in i :
                Waterpro.append(i)
                Waterpro1+=ScoreF(i)
            if  '暈開' in i :
                UnWaterpro.append(i)
                UnWaterpro1+=ScoreF(i)

            if '透亮' in i :
                Bright.append(i)
                Bright1+=ScoreF(i)

            if '飽和' in i :
                ColorSaturation.append(i)   
                ColorSaturation1+=ScoreF(i)

            if '顯色' in i :
                ShowColor.append(i)
                ShowColor1+=ScoreF(i)
            if  '上色' in i  or '上手' in i:
                EasytoCo.append(i)      
                EasytoCo1+=ScoreF(i)

            else:
                continue



        j+=1
    try:
        dic['遮瑕度']=round((cover1)*9/len(cover),4)
    except ZeroDivisionError:
        dic['遮瑕度']=0  
    try:
        dic['保濕度']=round((Water1-Dry1)*8/len(Water+Dry),4)
    except ZeroDivisionError:
        dic['保濕度']=0
    try:
        dic['持久度']=round((mainLong1-mainShort1)*7/len(mainLong+mainShort),4)
    except ZeroDivisionError:
        dic['持久度']=0
    try:
        dic['透亮度']=round((Bright1)*6/len(Bright),4)
    except ZeroDivisionError:
        dic['透亮度']=0 
    try:
        dic['推勻度']=round((blendout1-Unblendout1)*5/len(blendout+Unblendout),4)
    except ZeroDivisionError:
        dic['推勻度']=0   
        
    try:
        dic['自然度']=round((nature1)*4/len(nature),4)
    except ZeroDivisionError:
        dic['自然度']=0   
        
    try:
        dic['清爽度']=round((fresh1-unfresh1)*3/len(fresh+unfresh),4)
    except ZeroDivisionError:
        dic['清爽度']=0
        
            
    try:
        dic['服貼度']=round((stick1-Unstick1)*3/len(stick+Unstick),4)
    except ZeroDivisionError:
        dic['服貼度']=0
        
    


        
    dic['種類']='粉底液'
    dic[product_ID]=files[k].replace('.json','').split('/')[-1]
        
    product[files[k].replace('.json','').split('/')[-1]]=dic
    k+=1
with open('/Users/oz/Desktop/test/Foundation_score.json','w',encoding='utf-8') as f:
    json.dump(product,f)
product

# %%
唇膏:
保濕,持久,顯色,自然,透亮,飽和,推勻,遮,上色,黏膩

眼線筆:
暈開,上色,持久,顯色,飽和,推勻,透亮,保濕

眉筆:
上色,自然,持久,暈開,顯色,推勻,保濕

粉底液:
遮,保濕,持久,透亮,推勻,自然,清爽,浮粉

# %%
# Out:
# -6.25
